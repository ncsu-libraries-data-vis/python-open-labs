# %% [markdown]
# # Python Open Labs: Reading, exploring, and writing data with Pandas
#
# ## Setup
# With this Google Colaboratory (Colab) notebook open, click the "Copy to Drive" button that appears in the menu bar. The notebook will then be attached to your own user account, so you can edit it in any way you like -- you can even take notes directly in the notebook.
#
#
# ## Open Labs agenda
#
# 1.   **Guided activity**: One of the instructors will share their screen to work through the guided activity and teach concepts along the way.
#
# 2.   **Open lab time**: After the guided portion of the Open Lab, the rest of the time is for you to ask questions, work collaboratively, or have self-guided practice time. You will have access to instructors and peers for questions and support.
#
# Breakout rooms will be available if you would like to work in small groups. If you have trouble joining a room, ask in the chat to be moved into a room.
#
# ## Learning objectives
#
# By the end of our workshop today, we hope you'll understand what the pandas library is and be able to work with pandas data structures like a `Series` and a `DataFrame`.
#
# ## Today's Topics
# - What is pandas, and how does it relate to Python?
# - Importing and using pandas
# - How to read data into pandas
# - Common pandas data structures (`Series` and `DataFrame`)
# - Referencing data in a `DataFrame`
# - How to write data from pandas
#
# ## Questions during the workshop
#
# Please feel free to ask questions throughout the workshop.
#
# We have a second instructor who will available during the workshop. They will answer as able, and will collect questions with answers that might help everyone to be answered at the end of the workshop.
#
# The open lab time is when you will be able to ask more questions and work together on the exercises.

# %% [markdown]
# ### Using Jupyter Notebooks and Google Colaboratory
#
# Jupyter notebooks are a way to write and run Python code in an interactive way. They're quickly becoming a standard way of putting together data, code, and written explanations or visualizations into a single document and sharing that. There are a lot of ways that you can run Jupyter notebooks, including just locally on your computer, but we've decided to use Google's Colaboratory notebook platform for this workshop.  Colaboratory is “a Google research project created to help disseminate machine learning education and research.”  If you would like to know more about Colaboratory in general, you can visit the [Welcome Notebook](https://colab.research.google.com/notebooks/welcome.ipynb).
#
# Using the Google Colaboratory platform allows us to focus on learning and writing Python in the workshop rather than on setting up Python, which can sometimes take a bit of extra work depending on platforms, operating systems, and other installed applications. If you'd like to install a Python distribution locally, though, we're happy to help. Feel free to [get help from our graduate consultants](https://www.lib.ncsu.edu/dxl) or [schedule an appointment with Libraries staff](https://go.ncsu.edu/dvs-request).

# %% [markdown]
# ## Guided Instruction
# This week we're introducing the Pandas library for Python and working on importing, viewing, and referencing the data.
#
# In this section, we will work through examples using data from the [Museum of Modern Art (MoMA) research dataset](https://github.com/MuseumofModernArt/collection) containing records of all of the works that have been cataloged in the database of the MoMA collection.
#
# > "The Museum’s website features 89,695 artworks from 26,494 artists. This research dataset contains 138,151 records, representing all of the works that have been accessioned into MoMA’s collection and cataloged in our database. It includes basic metadata for each work, including title, artist, date made, medium, dimensions, and date acquired by the Museum. Some of these records have incomplete information and are noted as “not Curator Approved." - [MoMA Github repository for collection data](https://github.com/MuseumofModernArt/collection)
#
# We have split the dataset into several different subsections (paintings, sculptures, photographs, and artist information) and file types to use in activities. We will be referencing the data that we have prepared in our [Github repository for teaching datasets](https://github.com/ncsu-libraries-data-vis/teaching-datasets/tree/main/moma_data).

# %% [markdown]
# ### What is a Python library?
#
# A "Library" in this context is a package of code that adds to the functionality of Python. Base Python offers a lot of features, but not everything -- Python libraries can be imported at the beginning of your code to use for your specific purpose.
#
# For example, you may import Matplotlib to create graphs and plots, or Natural Language Toolkit (NLTK) to do natural language processing. Today we will be using the pandas library to manipulate a dataset.
#
# Google Colab has many popular libraries, including pandas, numpy, tensorflow, matplotlib, preinstalled, meaning you do not need to use pip or other package managers to install these libraries.

# %% [markdown]
# ### What is Pandas?
#
# Pandas is a high-level data manipulation tool first created in 2008 by Wes McKinney. The name comes from the term “panel data,” an econometrics term for data sets that include observations over multiple time periods for the same individuals.<sup>[[wikipedia](https://en.wikipedia.org/wiki/Pandas_(software))]</sup>
#
# From Jake Vanderplas’ book [**Python Data Science Handbook**](http://shop.oreilly.com/product/0636920034919.do):
#
# > As well as offering a convenient storage interface for labeled data, Pandas implements a number of powerful data operations familiar to users of both database frameworks and spreadsheet programs.
#
# #### What does Pandas do?
# * Reading and writing data from persistent storage
# * Cleaning, filtering, and otherwise preparing data
# * Calculating statistics and analyzing data
# * Visualization with help from Matplotlib
#
# We can learn more about Pandas by using the help window in Google Colab.

# %%
# Type the function with a question mark afterwards and run the code to pull up a help window.
# Here we will find out more about Pandas
pd?

# %% [markdown]
# ### Importing a Python library
#
# To use any library, we must import it into our Python document.

# %%
# Import the Pandas library as pd (callable in our code as pd)
import pandas as pd
pd?

# %% [markdown]
# ### Importing files into Pandas
# We have prepared the data from the MoMA dataset for this workshop. We will import those datasets into our notebook to use them for data analysis.
#
# Datasets can be stored in several types of files, including .csv, .json, .txt, .xls, .xlsx, and more. Here we will import a .csv file and a .json file.
#
# - [Preview the CSV file](https://raw.githubusercontent.com/ncsu-libraries-data-vis/teaching-datasets/main/moma_data/moma_paintings.csv)
# - [Preview the JSON file](https://raw.githubusercontent.com/ncsu-libraries-data-vis/teaching-datasets/main/moma_data/moma_sculptures.json)

# %% [markdown]
# CSV Files
#
# A comma separated values (CSV) file is a plain text file containing data separated by commas.

# %%
# Import a comma-sperated values (csv) file as a DataFrame

# The file location
csv_file_url = 'https://raw.githubusercontent.com/ncsu-libraries-data-vis/teaching-datasets/main/moma_data/moma_paintings.csv'

# Read in the file and print out the DataFrame
paintings_csv = pd.read_csv(csv_file_url)
paintings_csv.head()
# Out:
#                         Title         Artist ConstituentID  \
# 0          Rope and People, I      Joan Miró          4016
# 1         Fire in the Evening      Paul Klee          3130
# 2  Portrait of an Equilibrist      Paul Klee          3130
# 3                      Guitar  Pablo Picasso          4609
# 4                 Grandmother    Arthur Dove          1602
#
#                         Date  \
# 0  Barcelona, March 27, 1935
# 1                       1929
# 2                       1927
# 3          Paris, early 1919
# 4                       1925
#
#                                               Medium  \
# 0  Oil on cardboard mounted on wood, with coil of...
# 1                                   Oil on cardboard
# 2  Oil and collage on cardboard over wood with pa...
# 3           Oil, charcoal and pinned paper on canvas
# 4  Shingles, needlepoint, page from Concordance, ...
#
#                            Dimensions  \
# 0  41 1/4 x 29 3/8" (104.8 x 74.6 cm)
# 1   13 3/8 x 13 1/4" (33.8 x 33.3 cm)
# 2     24 7/8 x 15 3/4" (63.2 x 40 cm)
# 3         7' 1" x 31" (216 x 78.8 cm)
# 4       20 x 21 1/4" (50.8 x 54.0 cm)
#
#                                 CreditLine AccessionNumber Classification  \
# 0       Gift of the Pierre Matisse Gallery         71.1936       Painting
# 1  Mr. and Mrs. Joachim Jean Aberbach Fund        153.1970       Painting
# 2               Mrs. Simon Guggenheim Fund        195.1966       Painting
# 3               Gift of A. Conger Goodyear        384.1955       Painting
# 4  Gift of Philip L. Goodwin (by exchange)        636.1939       Painting
#
#              Department  ...  \
# 0  Painting & Sculpture  ...
# 1  Painting & Sculpture  ...
# 2  Painting & Sculpture  ...
# 3  Painting & Sculpture  ...
# 4  Painting & Sculpture  ...
#
#                                         ThumbnailURL Circumference (cm)  \
# 0  http://www.moma.org/media/W1siZiIsIjE2MDU0NiJd...                NaN
# 1  http://www.moma.org/media/W1siZiIsIjE3Njc2NyJd...                NaN
# 2  http://www.moma.org/media/W1siZiIsIjE3OTI4NSJd...                NaN
# 3  http://www.moma.org/media/W1siZiIsIjE1MDQ2MiJd...                NaN
# 4  http://www.moma.org/media/W1siZiIsIjI0NzA5NCJd...                NaN
#
#    Depth (cm) Diameter (cm) Height (cm)  Length (cm)  Weight (kg)  Width (cm)  \
# 0         NaN           NaN       104.8          NaN          NaN        74.6
# 1         NaN           NaN        33.8          NaN          NaN        33.3
# 2         NaN           NaN        60.3          NaN          NaN        36.8
# 3         NaN           NaN       215.9          NaN          NaN        78.7
# 4         NaN           NaN        50.8          NaN          NaN        54.0
#
#    Seat Height (cm)  Duration (sec.)
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# JSON Files
#
# JSON (JavaScript Object Notation) is a data storage format that uses name/value pairs to create objects and associative arrays. Learn more about [JSON files structure and syntax from W3Schools](https://www.w3schools.com/js/js_json_syntax.asp)

# %%
# Importing a JavaScript object notation (JSON) file

# The file location
json_file_url = 'https://raw.githubusercontent.com/ncsu-libraries-data-vis/teaching-datasets/main/moma_data/moma_sculptures.json'

# Read in the file and print out the DataFrame
sculptures_json = pd.read_json(json_file_url)
sculptures_json.head()
# Out:
#                                                    Title           Artist  \
# 73418                     Surface with Vibrating Texture  Getulio Alviani
# 73474  IN RELATION TO AN INCREASE IN QUANTITY REGARDL...  Lawrence Weiner
# 73564                               3 Standard Stoppages   Marcel Duchamp
# 73567  To Be Looked at (from the Other Side of the Gl...   Marcel Duchamp
# 73733                                          Revolving  Kurt Schwitters
#
#       ConstituentID               Date  \
# 73418           137               1964
# 73474          6288            1973-74
# 73564          1634      Paris 1913-14
# 73567          1634  Buenos Aires 1918
# 73733          5293               1919
#
#                                                   Medium  \
# 73418                          Brushed aluminum on board
# 73474               LANGUAGE + THE MATERIALS REFERRED TO
# 73564  Wood box 11 1/8 x 50 7/8 x 9" (28.2 x 129.2 x ...
# 73567  Oil, silver leaf, lead wire, and magnifying le...
# 73733  Wood, metal, cord, cardboard, wool, wire, leat...
#
#                            Dimensions                     CreditLine  \
# 73418   33 x 32 3/4" (83.6 x 83.2 cm)  Larry Aldrich Foundation Fund
# 73474             Dimensions variable              Given anonymously
# 73564                            None    Katherine S. Dreier Bequest
# 73567      Overall 22" (55.8 cm) high    Katherine S. Dreier Bequest
# 73733  48 3/8 x 35" (122.7 x 88.7 cm)        Advisory Committee Fund
#
#       AccessionNumber Classification            Department  ...  \
# 73418        105.1965      Sculpture  Painting & Sculpture  ...
# 73474        117.1975      Sculpture  Painting & Sculpture  ...
# 73564    149.1953.a-i      Sculpture  Painting & Sculpture  ...
# 73567        150.1953      Sculpture  Painting & Sculpture  ...
# 73733        231.1968      Sculpture  Painting & Sculpture  ...
#
#                                             ThumbnailURL Circumference (cm)  \
# 73418  http://www.moma.org/media/W1siZiIsIjIwODIwOCJd...                NaN
# 73474  http://www.moma.org/media/W1siZiIsIjMxODk1MSJd...                NaN
# 73564  http://www.moma.org/media/W1siZiIsIjEzODY0NSJd...                NaN
# 73567  http://www.moma.org/media/W1siZiIsIjI0MzI3MyJd...                NaN
# 73733  http://www.moma.org/media/W1siZiIsIjEyMjc3MCJd...                NaN
#
#        Depth (cm) Diameter (cm) Height (cm)  Length (cm)  Weight (kg)  \
# 73418         NaN           NaN        83.6          NaN          NaN
# 73474         NaN           NaN         NaN          NaN          NaN
# 73564         NaN           NaN        13.3          NaN          NaN
# 73567         NaN           NaN        49.5          NaN          NaN
# 73733         NaN           NaN       122.7          NaN          NaN
#
#        Width (cm)  Seat Height (cm)  Duration (sec.)
# 73418        83.2               NaN              NaN
# 73474         NaN               NaN              NaN
# 73564       120.0               NaN              NaN
# 73567        39.7               NaN              NaN
# 73733        88.7               NaN              NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Pandas data structures
#
# Pandas uses two main data structures: `Series` and `DataFrame`.
#
# <img src="https://raw.githubusercontent.com/NCSU-Libraries/data-viz-workshops/master/Data_Manipulation_with_Python/assets/nc_dataframes.png" alt="DataFrames are composed of Series" width="80%">

# %% [markdown]
# #### `Series`
# A `Series` is a one-dimensional array of indexed data, or a single column of data. It can be thought of as a specialized dictionary or a generalized NumPy array. You can learn more about the Series data type in the [Pandas documentation for Series](https://pandas.pydata.org/pandas-docs/stable/reference/series.html).

# %% [markdown]
# #### `DataFrame`
# A `DataFrame` is a two-dimensional array composed of one or more `Series`, similar to tabluar data (think of Excel). They can optionally have an `Index` and have flexible row indices and flexible column names.
#
# It can be thought of as a generalization of a two-dimensional NumPy array, or a specialization of a dictionary in which each column name maps to a `Series` of column data. You can learn more about the DataFrame data type in the [Pandas documentation for DataFrame](https://pandas.pydata.org/pandas-docs/stable/reference/frame.html).
#
# A `DataFrame` is made up of `Series` in a similar way in which a table is made up of columns. The only restriction is that each column must be of the same data type.  Many of the operations that can be performed on a `DataFrame` can also be performed on an individual `Series`.

# %%
# The csv file we imported earlier was stored in a DataFrame.
# Let's look at that data:
paintings_csv
# Out:
#                            Title          Artist ConstituentID  \
# 0             Rope and People, I       Joan Miró          4016
# 1            Fire in the Evening       Paul Klee          3130
# 2     Portrait of an Equilibrist       Paul Klee          3130
# 3                         Guitar   Pablo Picasso          4609
# 4                    Grandmother     Arthur Dove          1602
# ...                          ...             ...           ...
# 2355                Zacimba Gaba    Dalton Paula        132719
# 2356                       Zumbi    Dalton Paula        132719
# 2357                  Vertigo #2  Ouattara Watts        132954
# 2358        Lot 111113 (flare 1)  Donald Moffett          7435
# 2359           Unknown Pleasures    Matthew Wong        132956
#
#                            Date  \
# 0     Barcelona, March 27, 1935
# 1                          1929
# 2                          1927
# 3             Paris, early 1919
# 4                          1925
# ...                         ...
# 2355                       2020
# 2356                       2020
# 2357                       2011
# 2358                       2013
# 2359                       2019
#
#                                                  Medium  \
# 0     Oil on cardboard mounted on wood, with coil of...
# 1                                      Oil on cardboard
# 2     Oil and collage on cardboard over wood with pa...
# 3              Oil, charcoal and pinned paper on canvas
# 4     Shingles, needlepoint, page from Concordance, ...
# ...                                                 ...
# 2355  Oil, pencil, and gold leaf on two joined canvases
# 2356  Oil, pencil, and gold leaf on two joined canvases
# 2357  Acrylic, paper pulp, cut and pasted fabrics, a...
# 2358  Acrylic and lacquer on linen with cotton and a...
# 2359                                      Oil on canvas
#
#                                              Dimensions  \
# 0                    41 1/4 x 29 3/8" (104.8 x 74.6 cm)
# 1                     13 3/8 x 13 1/4" (33.8 x 33.3 cm)
# 2                       24 7/8 x 15 3/4" (63.2 x 40 cm)
# 3                           7' 1" x 31" (216 x 78.8 cm)
# 4                         20 x 21 1/4" (50.8 x 54.0 cm)
# ...                                                 ...
# 2355          24 × 17 3/4" (61 × 45.1 cm), in two parts
# 2356          24 × 17 3/4" (61 × 45.1 cm), in two parts
# 2357  118 1/4 × 165 1/2 × 3 3/4" (300.4 × 420.4 × 9....
# 2358                        54 × 44" (137.2 × 111.8 cm)
# 2359                        65 × 65" (165.1 × 165.1 cm)
#
#                                    CreditLine AccessionNumber Classification  \
# 0          Gift of the Pierre Matisse Gallery         71.1936       Painting
# 1     Mr. and Mrs. Joachim Jean Aberbach Fund        153.1970       Painting
# 2                  Mrs. Simon Guggenheim Fund        195.1966       Painting
# 3                  Gift of A. Conger Goodyear        384.1955       Painting
# 4     Gift of Philip L. Goodwin (by exchange)        636.1939       Painting
# ...                                       ...             ...            ...
# 2355                                      NaN       TR16514.1       Painting
# 2356                                      NaN       TR16514.2       Painting
# 2357                                      NaN         TR16516       Painting
# 2358                                      NaN         TR16517       Painting
# 2359                                      NaN         TR16518       Painting
#
#                 Department  ...  \
# 0     Painting & Sculpture  ...
# 1     Painting & Sculpture  ...
# 2     Painting & Sculpture  ...
# 3     Painting & Sculpture  ...
# 4     Painting & Sculpture  ...
# ...                    ...  ...
# 2355  Painting & Sculpture  ...
# 2356  Painting & Sculpture  ...
# 2357  Painting & Sculpture  ...
# 2358  Painting & Sculpture  ...
# 2359  Painting & Sculpture  ...
#
#                                            ThumbnailURL Circumference (cm)  \
# 0     http://www.moma.org/media/W1siZiIsIjE2MDU0NiJd...                NaN
# 1     http://www.moma.org/media/W1siZiIsIjE3Njc2NyJd...                NaN
# 2     http://www.moma.org/media/W1siZiIsIjE3OTI4NSJd...                NaN
# 3     http://www.moma.org/media/W1siZiIsIjE1MDQ2MiJd...                NaN
# 4     http://www.moma.org/media/W1siZiIsIjI0NzA5NCJd...                NaN
# ...                                                 ...                ...
# 2355                                                NaN                NaN
# 2356                                                NaN                NaN
# 2357                                                NaN                NaN
# 2358                                                NaN                NaN
# 2359                                                NaN                NaN
#
#       Depth (cm) Diameter (cm) Height (cm)  Length (cm)  Weight (kg)  \
# 0            NaN           NaN  104.800000          NaN          NaN
# 1            NaN           NaN   33.800000          NaN          NaN
# 2            NaN           NaN   60.300000          NaN          NaN
# 3            NaN           NaN  215.900000          NaN          NaN
# 4            NaN           NaN   50.800000          NaN          NaN
# ...          ...           ...         ...          ...          ...
# 2355    0.000000           NaN   60.960122          NaN          NaN
# 2356    0.000000           NaN   60.960122          NaN          NaN
# 2357    9.525019           NaN  300.355601          NaN          NaN
# 2358    0.000000           NaN  137.160274          NaN          NaN
# 2359    0.000000           NaN  165.100330          NaN          NaN
#
#       Width (cm)  Seat Height (cm)  Duration (sec.)
# 0      74.600000               NaN              NaN
# 1      33.300000               NaN              NaN
# 2      36.800000               NaN              NaN
# 3      78.700000               NaN              NaN
# 4      54.000000               NaN              NaN
# ...          ...               ...              ...
# 2355   45.085090               NaN              NaN
# 2356   45.085090               NaN              NaN
# 2357  420.370841               NaN              NaN
# 2358  111.760224               NaN              NaN
# 2359  165.100330               NaN              NaN
#
# [2360 rows x 24 columns]

# %%
# You can also view the "shape" of the Dataframe
# This tells you how many rows and columns there are
paintings_csv.shape
# Out:
# (2360, 24)

# %%
# A Series is a one-dimensional array, or one column of data
# When we take one column of a DataFrame, it is represented as a Series
artist = paintings_csv['Artist']
type(artist)
# Out:
# pandas.core.series.Series

# %%
# Now that we have created a Series, let's look at the data:
artist
# Out:
# 0            Joan Miró
# 1            Paul Klee
# 2            Paul Klee
# 3        Pablo Picasso
# 4          Arthur Dove
#              ...
# 2355      Dalton Paula
# 2356      Dalton Paula
# 2357    Ouattara Watts
# 2358    Donald Moffett
# 2359      Matthew Wong
# Name: Artist, Length: 2360, dtype: object

# %%
# You can also see the shape of a Series
# Since a Series only has one column, it will tell you how many rows there are
artist.shape
# Out:
# (2360,)

# %%
# You can convert a Series to a list with to_list()
artist.to_list()
# Out:
# ['Joan Miró',
#  'Paul Klee',
#  'Paul Klee',
#  'Pablo Picasso',
#  'Arthur Dove',
#  'Francis Picabia',
#  'Blinky Palermo',
#  'Pierre Roy',
#  'Paul Cézanne',
#  'Enrico Prampolini',
#  'Jankel Adler',
#  'Robert Delaunay',
#  'Jean Bazaine',
#  'Elmer Bischoff',
#  'Vasudeo S. Gaitonde',
#  'Barnett Newman',
#  'Preston Dickinson',
#  'Piet Mondrian',
#  'Pablo Picasso',
#  'James Edward Davis',
#  'Georges Braque',
#  'Francisco Borès',
#  'Wilson Bigaud',
#  'Franz Kline',
#  'Vasily Kandinsky',
#  'Hans Hofmann',
#  'Paul Gauguin',
#  'John Randall Bratby',
#  'Jean McEwen',
#  'James Francis Gill',
#  'Michael Gross',
#  'Check  Boterf',
#  'Glenn Ligon',
#  'Edward Hopper',
#  'Otto Dix',
#  'Niles Spencer',
#  'Frida Kahlo',
#  'Vasily Kandinsky',
#  'Alfonso Ossorio',
#  'Charles Hinman',
#  'Eduardo A. MacEntyre',
#  'James Rosenquist',
#  'David Alfaro Siqueiros',
#  'Emilio Pettoruti',
#  'Loren MacIver',
#  'Francis Picabia',
#  'Nassos Daphnis',
#  'Antonio Corpora',
#  'Mark Tobey',
#  'Leonardo Cremonini',
#  'Sam Francis',
#  'Agnes Martin',
#  'Kenneth Noland',
#  'Cy Twombly',
#  'Piero Manzoni',
#  'Thomas Hart Benton',
#  'John Kane',
#  'Max Beckmann',
#  'Antonio Ruiz',
#  'Julio Castellanos',
#  'Balcomb Greene',
#  'André Derain',
#  'Adolph Gottlieb',
#  'Burgoyne Diller',
#  'Grace Hartigan',
#  'Jackson Pollock',
#  'Larry Zox',
#  'Hyman Bloom',
#  'Henri Matisse',
#  'Lee Gatch',
#  'Giacomo Balla',
#  'Philip Guston',
#  'Richard Lindner',
#  'Ibrahim El-Salahi',
#  'Jackson Pollock',
#  'Georges Braque',
#  'Henri Matisse',
#  'Florine Stettheimer',
#  'Jasper Johns',
#  'James Jarvaise',
#  'Carl-Henning Pedersen',
#  'Tadasky (Tadasuke Kuwayama)',
#  'Stuart Davis',
#  'Ida E. Fischer',
#  'Willi Baumeister',
#  'Jasper Johns',
#  'Robert Goodnough',
#  'Ellsworth Kelly',
#  'Max Schnitzler',
#  'Fletcher Martin',
#  'Alberto da Veiga Guignard',
#  'Theora Hamblett',
#  'Gustav Klimt',
#  'Jasper Johns',
#  'Raphael Soyer',
#  'Joan Miró',
#  'Grace Hartigan',
#  'Fernand Léger',
#  'Joan Miró',
#  'Max Ernst',
#  'Rafael Moreno',
#  'Herman Rose',
#  'Ernst Ludwig Kirchner',
#  'Pablo Picasso',
#  'Lucian Freud',
#  'James McGarrell',
#  'Amedeo Modigliani',
#  'Pablo Picasso',
#  'Paul Klee',
#  'Antoni Tàpies',
#  'Francis Alÿs',
#  'Walt Kuhn',
#  'Piet Mondrian',
#  'Oskar Kokoschka',
#  'Armando Morales Sequeira',
#  'Liubov Popova',
#  'Ger Lataster',
#  'Elizabeth Peyton',
#  'Alberto Giacometti',
#  'Robert Motherwell',
#  'Victor Vasarely',
#  'Paul Cézanne',
#  'Andrew Wyeth',
#  'René Magritte',
#  'Roberto Matta',
#  'August Macke',
#  'Jan Müller',
#  'Henri Matisse',
#  'Honoré Sharrer',
#  'Roberto Ossaye',
#  'George McNeil',
#  'Paul Cézanne',
#  'Max Weber',
#  'Joan Miró',
#  'László Moholy-Nagy',
#  'Abraham Rattner',
#  'John Tunnard',
#  'Max Weber',
#  'John Piper',
#  'Emil Nolde',
#  'Otto Mueller',
#  'Jeanne Reynal',
#  'Morgan Russell',
#  'Mark Rothko',
#  'Paul Cézanne',
#  'Stanley Spencer',
#  'Zoran Mušič',
#  'Iaroslav Serpan',
#  'Will Barnet',
#  'Diego Rivera',
#  'Pierre Soulages',
#  'Christian Bérard',
#  'Ilya Bolotowsky',
#  'Niles Spencer',
#  'Christian Bérard',
#  'Larry Rivers',
#  'Myron Stout',
#  'Max Beckmann',
#  'Oskar Kokoschka',
#  'Jean-Paul Riopelle',
#  'Giuseppe Guerreschi',
#  'Kumi Sugaï',
#  'Modest Cuixart',
#  'Susan Rothenberg',
#  'Oliver Jackson',
#  'Richard Oelze',
#  'Theodoros Stamos',
#  'Antoni Tàpies',
#  'Donald Sultan',
#  'Alice Neel',
#  'Neil Jenney',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Jacob Lawrence',
#  'Nicolas de Staël',
#  'Alice Neel',
#  'Peter Blume',
#  'Maria Helena Vieira da Silva',
#  'Wols (A. O. Wolfgang Schulze)',
#  'Arthur B. Davies',
#  'Mariano (Mariano Rodríguez)',
#  'Raoul Ubac',
#  'Pablo Picasso',
#  'Tim Rollins, K.O.S. (Kids of Survival), Angel Abreu, Jose Burges, Robert Delgado, George Garces, Richard Lulo, Nelson Montes, José Parissi, Carlos Rivera, Annette Rosado, Nelson Ricardo Savinon',
#  'Arthur B. Davies',
#  'Jack Tworkov',
#  'Raymond Parker',
#  'Alex Katz',
#  'Clara McDonald Williamson',
#  'William Ronald',
#  'Pablo Picasso',
#  'Roberto Matta',
#  'Man Ray (Emmanuel Radnitzky)',
#  'Meret Oppenheim',
#  'Theodoros Stamos',
#  'Antoine Pevsner',
#  'Sarai Sherman',
#  'Benny Andrews',
#  'Mikhail Larionov',
#  'Dorothea Rockburne',
#  'Mordecai Ardon',
#  'Séraphine Louis',
#  'Mark Rothko',
#  'Alan Shields',
#  'Peter Blume',
#  'Paul Burlin',
#  'Bruce Boice',
#  "Allan D'Arcangelo",
#  'Hedda Sterne',
#  'Toni Costa',
#  'Richard Tuttle',
#  'Wojciech Fangor',
#  'Richard Smith',
#  'Paul Gauguin',
#  'Marcos Grigorian',
#  'George Grosz',
#  'Fernand Léger',
#  'Paul Gauguin',
#  'Hans Hartung',
#  'Lothar Quinte',
#  'Fritz Glarner',
#  'Mohsen Vaziri Moghaddam',
#  'Israel Litwak',
#  'Pablo Picasso',
#  'André Marchand',
#  'William Bailey',
#  'Joan Miró',
#  'Bradley Walker Tomlin',
#  'Red Grooms',
#  'René Robert Bouché',
#  'Philip Guston',
#  'Raoul Dufy',
#  'On Kawara',
#  'Preston Dickinson',
#  'Jorge Damiani',
#  'On Kawara',
#  'Ellsworth Kelly',
#  'Jean Dubuffet',
#  'On Kawara',
#  'Umberto Boccioni',
#  'Richard Artschwager',
#  'Otto Dix',
#  'Roberto Matta',
#  'Richard Lindner',
#  'Umberto Boccioni',
#  'Milton Avery',
#  "Georgia O'Keeffe",
#  'Guy Pène du Bois',
#  'Marsden Hartley',
#  'Virginia Admiral',
#  'Umberto Boccioni',
#  'Leon Polk Smith',
#  'Georg Baselitz',
#  'Balthus (Baltusz Klossowski de Rola)',
#  'Pierre Bonnard',
#  'Jimmy Ernst',
#  'Cundo Bermúdez',
#  'Georges Braque',
#  'Paul Cézanne',
#  'Robert Colescott',
#  'Vern Blosum',
#  "Georgia O'Keeffe",
#  'Eva Hesse',
#  'James Francis Gill',
#  'Eva Hesse',
#  'Piet Mondrian',
#  'Jimmy Ernst',
#  'Enrico Donati',
#  'Lester F. Johnson',
#  'Hans Hofmann',
#  'Jean (Hans) Arp',
#  'Robert Hansen',
#  'Joan Snyder',
#  'Alex Katz',
#  'Robert Motherwell',
#  'Richard Lindner',
#  'Guido Molinari',
#  'Jean Hélion',
#  'Pablo Picasso',
#  'Ida Applebroog',
#  'Willem de Kooning',
#  'Jackson Pollock',
#  'Maurice Sievan',
#  'Yves Tanguy',
#  'Roger van Rogger',
#  'Henri Matisse',
#  'David Simpson',
#  'Morris Louis',
#  'Rufino Tamayo',
#  'Elsa Schmid',
#  'Georges Rouault',
#  'Tom Wesselmann',
#  'Robert Rauschenberg',
#  'Henri Matisse',
#  'Amelia Peláez Del Casal',
#  'Maurice de Vlaminck',
#  'Joan Brown',
#  'Pablo Picasso',
#  'Jackson Pollock',
#  'Harry Zolotow',
#  'Pablo Picasso',
#  'Helen Frankenthaler',
#  'Ad Reinhardt',
#  'Juan Gris',
#  'Natalia Goncharova',
#  'André Masson',
#  'Sean Scully',
#  'Max Ernst',
#  'Bernard Buffet',
#  'Renato Guttuso',
#  'Knud Merrild',
#  'Paul Signac',
#  'Henri Matisse',
#  'Giorgio de Chirico',
#  'Amedeo Modigliani',
#  'Giorgio de Chirico',
#  'Andy Warhol',
#  'Arshile Gorky',
#  'Joseph Mellor Hanson',
#  'Miguel Ocampo',
#  'John Kane',
#  'Paul Klee',
#  'Kurt Seligmann',
#  'László Moholy-Nagy',
#  'Pablo Picasso',
#  'László Moholy-Nagy',
#  'Chaim Soutine',
#  'Roy Adzak',
#  'Pablo Picasso',
#  'Albert Tucker',
#  'Gene Davis',
#  'Joan Miró',
#  'Genichiro Inokuma',
#  'Jake Berthot',
#  'Forrest Bess',
#  'Edwin Dickinson',
#  'Louis Cane',
#  'Albert Bloch',
#  'Richard Bosman',
#  'Richard Pousette-Dart',
#  'André Derain',
#  'Joan Josep Tharrats',
#  'Eugene Fernandez Granell',
#  'Sam Francis',
#  'David Alfaro Siqueiros',
#  'Arthur Dove',
#  'Édouard Vuillard',
#  'Ralph Goings',
#  'Jean Dubuffet',
#  'Rico Lebrun',
#  'Frida Kahlo',
#  'Georges Braque',
#  'Fernand Léger',
#  'André Masson',
#  'Simon Hantaï',
#  'Paul Burlin',
#  'Agam (Yaacov Agam)',
#  'Leonard French',
#  'Al Held',
#  'Jasper Johns',
#  'Peter Young',
#  'Donald Judd',
#  'Pablo Picasso',
#  'Ben Cunningham (Benjamin Frazier Cunningham)',
#  'Jasper Johns',
#  'Paul Klee',
#  'Piero Dorazio',
#  'Ronald Markman',
#  'Franz Kline',
#  'Willem de Kooning',
#  'Chuck Close',
#  'William Gropper',
#  'Eugenie Baizerman',
#  'Jorge Eielson',
#  'Mark Lancaster',
#  'Robert Kushner',
#  'Henri Matisse',
#  'Pamela Bianco',
#  'R. B. Kitaj',
#  'Sigmar Polke',
#  'Otto Freundlich',
#  'Seiji Chokai',
#  'Jane Wilson',
#  'Gandy Brodie',
#  'Karel Appel',
#  'Elizabeth Murray',
#  'André Masson',
#  'Rudolf Baranik',
#  'Giorgio de Chirico',
#  'Zbigniew Makowski',
#  'Francis Celentano',
#  'Gastone Novelli',
#  'Ger van Elk',
#  'Aleksandr Rodchenko',
#  'Romare Bearden',
#  'Horia Damian',
#  'Émile Bernard',
#  'Oli Sihvonen',
#  'Arnold Schmidt',
#  'Jules Olitski',
#  'Audrey Flack',
#  'Aleksandr Rodchenko',
#  'Jorge Damiani',
#  'Jean Dubuffet',
#  'Roland Dorcély',
#  'Jean Dubuffet',
#  'Walter Zehringer',
#  'Max Ernst',
#  'Pablo Picasso',
#  'Robyn Denny',
#  'Joan Miró',
#  'Henri Matisse',
#  'Alfred Jensen',
#  'Leon Golub',
#  'Nicholas Krushenick',
#  'Robert Motherwell',
#  'Agustín Fernández',
#  'Ahmed Yacoubi',
#  'Peter Young',
#  'Kenneth Noland',
#  'Franz Marc',
#  'Arnold Friedman',
#  'Zvi Gali',
#  'James Henry Daugherty',
#  'Peter Saul',
#  'Philip Evergood',
#  'Pierre Soulages',
#  'Richard Hamilton',
#  'Jim Nutt',
#  'Stuart Davis',
#  'Sam Joseph Ntiro',
#  'Octave Landuyt',
#  'Wayne Thiebaud',
#  'Robert Rauschenberg',
#  'Georges Braque',
#  'Evert Lundquist',
#  'Robert Rauschenberg',
#  'Gwen John',
#  'Albert Tucker',
#  'Henri Matisse',
#  'Frans Krajcberg',
#  'Georges-Pierre Seurat',
#  'Gregory Amenoff',
#  'Malcolm Morley',
#  'Pierre Roy',
#  'André Derain',
#  'Octave Landuyt',
#  'Frank Bowling',
#  'Bruno Ceccobelli',
#  'Andy Warhol',
#  'Graham Sutherland',
#  'Enrico Donati',
#  'Jean Dubuffet',
#  'Milton Avery',
#  'Richard Lytle',
#  'Erol (Erol Akyavas)',
#  'Gilbert & George, Gilbert Proesch, George Passmore',
#  'Juan Gris',
#  'Neil Jenney',
#  'Juan Gris',
#  'Stuart Davis',
#  'George Ault',
#  'Robert Motherwell',
#  'Gary Stephan',
#  'René Magritte',
#  'Jack Levine',
#  'Thomas Wilfred',
#  'Richard Tuttle',
#  'Robert Mangold',
#  'A. E. Gallatin',
#  'Manolo Millares',
#  'Robert Ryman',
#  'Theo van Doesburg',
#  'Robert Ryman',
#  'John Atherton',
#  'Giorgio de Chirico',
#  'Claude Viallat',
#  'Charles Seliger',
#  'Larry Rivers',
#  'David Hockney',
#  'Jewett Campbell',
#  'Karl Knaths',
#  'Irving Kriesberg',
#  'Patrick Scott',
#  'Édouard Vuillard',
#  'Fernand Léger',
#  'František Kupka',
#  'Ben Shahn',
#  'Pierre Roy',
#  'Horace Pippin',
#  'André Derain',
#  'Joseph Stella',
#  'Ad Reinhardt',
#  "Georgia O'Keeffe",
#  'Knud Merrild',
#  'Susan Rothenberg',
#  'Charles Sheeler',
#  'Marsden Hartley',
#  'Marc Chagall',
#  'Heinrich Campendonk',
#  'Pablo Picasso',
#  'John Covert',
#  'Marcel Duchamp',
#  'Morgan Russell',
#  'Giuseppe Capogrossi',
#  'René Vincent',
#  'Brice Marden',
#  'John Baldessari',
#  'Jack Levine',
#  'Ellsworth Kelly',
#  'Max Ernst',
#  'Piet Mondrian',
#  'David Deutsch',
#  'Max Weber',
#  'Robert Motherwell',
#  'Yvonne Jacquette',
#  'Karl Schmidt-Rottluff',
#  'Giorgio de Chirico',
#  'Paul Klee',
#  'Sidney Goodman',
#  'Ernest  Trova',
#  'Karl Schmidt-Rottluff',
#  'Fritz Winter',
#  'Salvador Dalí',
#  'Amelia Peláez Del Casal',
#  'Henri Matisse',
#  'Sophie Calle',
#  'Walter Quirt',
#  'Joan Miró',
#  'Henri Matisse',
#  'Richard Artschwager',
#  'Amédée Ozenfant',
#  'Henri Matisse',
#  'Rufino Tamayo',
#  'Roy Lichtenstein',
#  'Charles Sheeler',
#  'Thomas Wilfred',
#  'Maurice Prendergast',
#  'Gilbert & George, Gilbert Proesch, George Passmore',
#  'Gerhard Richter',
#  'Attilio Salemme',
#  'Fernand Léger',
#  'El Lissitzky',
#  'Edwin Dickinson',
#  'Mordecai Ardon',
#  'Marcel Duchamp',
#  'Oscar Domínguez',
#  'Jose Antonio Fernández-Muro',
#  'Georges Braque',
#  'Adolph Gottlieb',
#  'Elmer Schooley',
#  'Pablo Picasso',
#  'Pablo Picasso',
#  'Fernand Léger',
#  'Piet Mondrian',
#  'Felix Gonzalez-Torres',
#  'Karel Appel',
#  'On Kawara',
#  'Anselm Kiefer',
#  'Armando Pizzinato',
#  'Jackson Pollock',
#  'Jean Dubuffet',
#  'Andy Warhol',
#  'Alan Reynolds',
#  'Alan Davie',
#  'Richard Diebenkorn',
#  'Agam (Yaacov Agam)',
#  'Fernand Léger',
#  'Georges Ribemont-Dessaignes',
#  'William Baziotes',
#  'Helen Frankenthaler',
#  'Max Ernst',
#  'Brice Marden',
#  'Attilio Salemme',
#  'Paul Cézanne',
#  'Eric Fischl',
#  'Brice Marden',
#  'Attilio Salemme',
#  'Sonia Delaunay-Terk',
#  'Robert Natkin',
#  'Malcolm Morley',
#  'Kees van Dongen',
#  'John Levee',
#  'Janet Sobel',
#  'André Derain',
#  'Robin Winters',
#  'Vincent van Gogh',
#  'Sigmar Polke',
#  'Gérard Schneider',
#  'Alfred Manessier',
#  'Sigmar Polke',
#  'Georges Mathieu',
#  'Enrique Zañartu',
#  'Thomas Chimes',
#  'Jonathan Borofsky',
#  'Sigmar Polke',
#  'Henri Matisse',
#  'Sigmar Polke',
#  'Rufino Tamayo',
#  'Fairfield Porter',
#  'Philip Guston',
#  'Sigmar Polke',
#  'Henri Matisse',
#  'Emilio Rodríguez Larraín',
#  'Philip Guston',
#  'Robert Ryman',
#  'Robert Ryman',
#  'José Clemente Orozco',
#  'Joseph Stella',
#  'Gino De Dominicis',
#  'Joseph Glasco',
#  'Ronald Bladen',
#  'Robert Mangold',
#  'Robert Rauschenberg',
#  'Ralph Humphrey',
#  'Jacques Villon',
#  'David Alfaro Siqueiros',
#  'Joe Goode',
#  'Eugene Berman',
#  'Joan Miró',
#  'Jean Dubuffet',
#  'Nedo Mion Ferrario',
#  'Katherine Porter',
#  'Anselm Kiefer',
#  'Onofrio A. Pacenza',
#  'Fairfield Porter',
#  'Lee Krasner',
#  'Frank Stella',
#  'Pablo Picasso',
#  'Jacques Villon',
#  'Mark Tansey',
#  'Morris Louis',
#  'Chuck Close',
#  'Tom Wesselmann',
#  'Robert Rauschenberg',
#  'Odilon Redon',
#  'Jean Charlot',
#  'Odilon Redon',
#  'Odilon Redon',
#  'Odilon Redon',
#  'Yves Tanguy',
#  'Odilon Redon',
#  'Odilon Redon',
#  'Roger de La Fresnaye',
#  'Odilon Redon',
#  'László Moholy-Nagy',
#  'Marcel Broodthaers',
#  'Odilon Redon',
#  'Eugene Berman',
#  'Henri Matisse',
#  'Odilon Redon',
#  'Theo van Doesburg',
#  'Tom Wesselmann',
#  'Odilon Redon',
#  'Mikhail Larionov',
#  'Odilon Redon',
#  'Ivan LeLorraine Albright',
#  'René Brô',
#  'Max Ernst',
#  'Odilon Redon',
#  'Joan Miró',
#  'William Baziotes',
#  'Francis Bacon',
#  'Sally Hazelet Drummond',
#  'Marcel Broodthaers',
#  'Odilon Redon',
#  'Patrick Henry Bruce',
#  'Sigmar Polke',
#  'Odilon Redon',
#  'Daniel Buren',
#  'Arnulf Rainer',
#  'Odilon Redon',
#  'Gerhard Richter',
#  'Odilon Redon',
#  'Alex Katz',
#  'Edward Ruscha',
#  'Odilon Redon',
#  'Pierre Clerk',
#  'Bedri Rahmi',
#  'Arshile Gorky',
#  'Andy Warhol',
#  'Odilon Redon',
#  'Carlo Carrà',
#  'Larry Rivers',
#  'Robert Irwin',
#  'Christopher Wool',
#  'Odilon Redon',
#  'Robert Colquhoun',
#  'Robert Kabak',
#  'Franz Kline',
#  'Odilon Redon',
#  'Arshile Gorky',
#  'Lee Krasner',
#  'Odilon Redon',
#  'Willem de Kooning',
#  'Odilon Redon',
#  'Robert Mangold',
#  'Odilon Redon',
#  'Barnett Newman',
#  'Jackson Pollock',
#  'Enzo Cucchi',
#  'Piet Mondrian',
#  'Claude Monet',
#  'Ron Davis',
#  'Piet Mondrian',
#  'Jo Baer',
#  'Ralph Humphrey',
#  'Balthus (Baltusz Klossowski de Rola)',
#  'Ad Reinhardt',
#  'James Brooks',
#  'René Magritte',
#  'Barnett Newman',
#  'Kazimir Malevich',
#  'Edward Hopper',
#  'Kenzo Okada',
#  'Frederick Papsdorf',
#  'Afro (Afro Basaldella)',
#  'Reuven Rubin',
#  'Henri Rousseau',
#  'Umberto Boccioni',
#  'Robert MacBryde',
#  'Pavel Tchelitchew',
#  'Edmondo Bacci',
#  'Otto Dix',
#  'Francis Bacon',
#  'Howard Mehring',
#  'Max Beckmann',
#  'Edward Corbett',
#  'Luis Fernando Benedit',
#  'Ree Morton',
#  'Max Ernst',
#  'Eugene Berman',
#  'Marina Stern',
#  'Alberto Giacometti',
#  'Edward Ruscha',
#  'Piet Mondrian',
#  'Sandra Blow',
#  'Lyonel Feininger',
#  'Alberto Giacometti',
#  'Stefan Knapp',
#  'Lyonel Feininger',
#  'Lyonel Feininger',
#  'André Masson',
#  'Kirsten Kraa',
#  'Le Corbusier (Charles-Édouard Jeanneret)',
#  'Erich Buchholz',
#  'Norman Bluhm',
#  'Max Ernst',
#  'Julian E. Levi',
#  'Reginald Marsh',
#  'Jules Olitski',
#  'Joan Miró',
#  'Pablo Picasso',
#  'Paul-Émile Borduas',
#  'Thomas Sills',
#  'Pierre Bonnard',
#  'Max Ernst',
#  'Fritz Glarner',
#  'Enzo Cucchi',
#  'Komar and Melamid, Vitaly Komar, Aleksandr Danilovich Melamid',
#  'Georges-Pierre Seurat',
#  'Barbara Kruger',
#  'Raoul Dufy',
#  'Herbert Bayer',
#  'Philomé Obin',
#  'Robert Longo',
#  "Roderic O'Conor",
#  'André Masson',
#  'Joan Miró',
#  'Paul Klee',
#  'Giacomo Balla',
#  'Larry Poons',
#  'Elizabeth Murray',
#  'Giacomo Balla',
#  'Michelle Stuart',
#  'Henri Matisse',
#  'Jan Lebenstein',
#  'Terry Winters',
#  'Llyn Foulkes',
#  'Ernst Ludwig Kirchner',
#  'René Pierre Tal-Coat',
#  'Pablo Picasso',
#  'Jack Tworkov',
#  'Marc Chagall',
#  'Chaim Soutine',
#  'Pablo Picasso',
#  'Josef Albers',
#  'Marc Chagall',
#  'Maurice Sterne',
#  'Josef Albers',
#  'Shirley Jaffe',
#  'Clyfford Still',
#  'Jasper Johns',
#  'Frida Kahlo',
#  'André Derain',
#  'Pablo Picasso',
#  'Ross Bleckner',
#  'Katherine S. Dreier',
#  'Fernando Botero',
#  'Pablo Picasso',
#  'Rackstraw Downes',
#  'Jean Dubuffet',
#  'Victor Vasarely',
#  'Salvatore Fiume',
#  'Joaquín Torres-García',
#  'Emilio Vedova',
#  'Elizabeth Murray',
#  'Theodor Werner',
#  'Emilio Vedova',
#  'Elizabeth Murray',
#  'Thomas Chimes',
#  'Christo',
#  'Robert Rauschenberg',
#  'Karl Hofer',
#  'Carlos Cruz-Diez',
#  'Markus Lüpertz',
#  'Karin Sander',
#  'Stephen Greene',
#  'Georges-Pierre Seurat',
#  'David Salle',
#  'Giorgio Morandi',
#  'Chuck Close',
#  'Marcello Muccini',
#  'Robert Indiana',
#  'Agnes Martin',
#  'George Sugarman',
#  'Gino Severini',
#  'Gino Severini',
#  'Jean Dubuffet',
#  'Larry Rivers',
#  'Rufino Tamayo',
#  'Reuben Tam',
#  'Philippe Hosiasson',
#  'Jóhannes Sveinsson Kjarval',
#  'Nagwaraba',
#  'Alfred H. Maurer',
#  'Ronald Bladen',
#  'Roy Lichtenstein',
#  'Mel Bochner',
#  'Fernand Léger',
#  'Michelangelo Pistoletto',
#  'Mel Bochner',
#  'Yasuo Kuniyoshi',
#  'Josef Albers',
#  'Antonio Segui',
#  'Maurice Utrillo',
#  'Mel Bochner',
#  'Édouard Vuillard',
#  'Mel Bochner',
#  'John Walker',
#  'Joan Witek',
#  'Salvador Dalí',
#  'Maurice Sterne',
#  'Vasily Kandinsky',
#  'Vasily Kandinsky',
#  'Martin Kippenberger',
#  'Robert Moskowitz',
#  'Paul Klee',
#  'André Bauchant',
#  'Ronnie Landfield',
#  'Henri Matisse',
#  'André Derain',
#  'Jean Dubuffet',
#  'Anselm Kiefer',
#  'Fannie Hillsmith',
#  'Agnes Martin',
#  'Joseph Ndandarika',
#  'William Congdon',
#  'Fernand Léger',
#  'Mohan B. Samant',
#  'Arshile Gorky',
#  'José María Sicilia',
#  'Conrad Marca-Relli',
#  'Jackson Pollock',
#  'Tony Smith',
#  'Yves Tanguy',
#  'Jean Lurçat',
#  'Robert Delaunay',
#  'Arthur Osver',
#  'Sidney Nolan',
#  'J. Trevor Wood',
#  'Arshile Gorky',
#  'Irene Rice Pereira',
#  'Emil Nolde',
#  'Henri Matisse',
#  'Pablo Picasso',
#  'Stanislao Lepri',
#  'Kay Sage',
#  'Robert Motherwell',
#  'Pavel Tchelitchew',
#  'Walter Richard Sickert',
#  'Pablo Picasso',
#  'Graham Sutherland',
#  'Stanton Macdonald-Wright',
#  'Pablo Picasso',
#  'Stanton Macdonald-Wright',
#  'Irene Rice Pereira',
#  'Morgan Russell',
#  'Bradley Walker Tomlin',
#  'Morgan Russell',
#  'Gerhard Richter',
#  'John Baldessari',
#  'Gerhard Richter',
#  'Jim Dine',
#  'Elizabeth Murray',
#  'Eric Fischl',
#  'Ellen Gallagher',
#  'Richard Anuszkiewicz',
#  'Henri Matisse',
#  'Mowry Thatcher Baden',
#  'Larry Rivers',
#  'Lois Lane',
#  'David Novros',
#  'Raymond Parker',
#  'John Baldessari',
#  'Sue Williams',
#  'Bernard Cohen',
#  'Frank Stella',
#  'André Lanskoy',
#  'Roy Lichtenstein',
#  'Philip Guston',
#  'Agnes Martin',
#  'Philip Guston',
#  'Henri Matisse',
#  'Philip Guston',
#  'Joan Mitchell',
#  'Philip Guston',
#  'On Kawara',
#  'Patrick J. Sullivan',
#  'George Tooker',
#  'Claude Monet',
#  'Alex Colville',
#  'Pablo Picasso',
#  'Miroslav Sutej',
#  'Georges Braque',
#  'David Salle',
#  'Henri Matisse',
#  'Ulysse Comtois',
#  'Philip Taaffe',
#  'Henri Matisse',
#  'Graham Coughtry',
#  'André Masson',
#  'Henri Matisse',
#  'Adolph Gottlieb',
#  'William Kurelek',
#  'Bob Thompson',
#  'Lynton Wells',
#  'Alexander Liberman',
#  'Carroll Dunham',
#  "Allan D'Arcangelo",
#  'Saliba Douaihy',
#  'Richard Pettibone',
#  'Richard Pettibone',
#  'Richard Pettibone',
#  'Richard Pettibone',
#  'Richard Pettibone',
#  'Richard Pettibone',
#  'Richard Pettibone',
#  'Richard Pettibone',
#  'Richard Pettibone',
#  'Richard Pettibone',
#  'Joan Mitchell',
#  'Mel Bochner',
#  'Henri Matisse',
#  'Kazuo Nakamura',
#  'Malcolm Bailey',
#  'John Opper',
#  'Günther Förg',
#  'Jean Hélion',
#  'Mark Rothko',
#  'Mark Innerst',
#  'Günther Förg',
#  'Evsa Model',
#  ...]

# %% [markdown]
# ### Exploring your data
#
# Now that we have our data, we can use Pandas to explore our data for analysis. This can be useful if you are new to a dataset to see what's there and how you should start analyzing.

# %% [markdown]
# #### View DataFrame column labels
#
# Our DataFrame has 25 columns. We can quickly view the label names for each column using the DataFrame `columns` property.

# %%
# View column labels (headers)
paintings_csv.columns
# Out:
# Index(['Title', 'Artist', 'ConstituentID', 'Date', 'Medium', 'Dimensions',
#        'CreditLine', 'AccessionNumber', 'Classification', 'Department',
#        'DateAcquired', 'Cataloged', 'ObjectID', 'URL', 'ThumbnailURL',
#        'Circumference (cm)', 'Depth (cm)', 'Diameter (cm)', 'Height (cm)',
#        'Length (cm)', 'Weight (kg)', 'Width (cm)', 'Seat Height (cm)',
#        'Duration (sec.)'],
#       dtype='object')

# %% [markdown]
# #### View summaries of a DataFrame
#
# We can quickly generate summaries of our DataFrame to observe some basic statistics and information such as column data types and non-null value counts.

# %%
# Get summary statistics of DataFrame columns using "describe()" (only includes
# numerical data types)
paintings_csv.describe()
# Out:
#             ObjectID  Circumference (cm)  Depth (cm)  Diameter (cm)  \
# count    2360.000000                 0.0  406.000000      12.000000
# mean    99988.147458                 NaN    8.087142     138.357934
# std     50332.803948                 NaN   38.000817      61.507546
# min     33621.000000                 NaN    0.000000      21.300000
# 25%     79072.750000                 NaN    0.000000     116.190025
# 50%     79853.500000                 NaN    0.000000     153.850000
# 75%     82366.500000                 NaN    5.000000     182.900000
# max    417640.000000                 NaN  647.700000     203.200000
#
#        Height (cm)  Length (cm)  Weight (kg)   Width (cm)  Seat Height (cm)  \
# count  2330.000000          0.0     3.000000  2327.000000               0.0
# mean    122.422894          NaN    96.285524   130.379904               NaN
# std      79.589140          NaN    71.635359   151.111933               NaN
# min       0.000000          NaN    18.097500     0.000000               NaN
# 25%      60.970091          NaN    65.048787    60.000000               NaN
# 50%     104.150000          NaN   112.000073    97.200000               NaN
# 75%     180.330271          NaN   135.379537   167.640335               NaN
# max    1011.000000          NaN   158.759000  4663.449300               NaN
#
#        Duration (sec.)
# count              0.0
# mean               NaN
# std                NaN
# min                NaN
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max                NaN

# %%
# Get summary statistics of single column using "describe()"
paintings_csv['Artist'].describe()
# Out:
# count              2359
# unique             1026
# top       Pablo Picasso
# freq                 55
# Name: Artist, dtype: object

# %%
# Summarize column data types, non-null values, and memory usage using "info()"
paintings_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2360 entries, 0 to 2359
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               2360 non-null   object
#  1   Artist              2359 non-null   object
#  2   ConstituentID       2359 non-null   object
#  3   Date                2353 non-null   object
#  4   Medium              2359 non-null   object
#  5   Dimensions          2355 non-null   object
#  6   CreditLine          2353 non-null   object
#  7   AccessionNumber     2360 non-null   object
#  8   Classification      2360 non-null   object
#  9   Department          2360 non-null   object
#  10  DateAcquired        2350 non-null   object
#  11  Cataloged           2360 non-null   object
#  12  ObjectID            2360 non-null   int64
#  13  URL                 2295 non-null   object
#  14  ThumbnailURL        2108 non-null   object
#  15  Circumference (cm)  0 non-null      float64
#  16  Depth (cm)          406 non-null    float64
#  17  Diameter (cm)       12 non-null     float64
#  18  Height (cm)         2330 non-null   float64
#  19  Length (cm)         0 non-null      float64
#  20  Weight (kg)         3 non-null      float64
#  21  Width (cm)          2327 non-null   float64
#  22  Seat Height (cm)    0 non-null      float64
#  23  Duration (sec.)     0 non-null      float64
# dtypes: float64(9), int64(1), object(14)
# memory usage: 442.6+ KB

# %% [markdown]
# #### Referencing and indexing a DataFrame

# %% [markdown]
# Referencing Rows

# %%
# Reference a row by index label
# Returns a Series

# Access first row of paintings_csv by index label
# In this case the index label is 0
paintings_csv.loc[0]

# Access first row of sculptures_json by index label
# In this case the index label is not 0
# sculptures_json.loc[0]
sculptures_json.loc[73418]
# Out:
# Title                                    Surface with Vibrating Texture
# Artist                                                  Getulio Alviani
# ConstituentID                                                       137
# Date                                                               1964
# Medium                                        Brushed aluminum on board
# Dimensions                                33 x 32 3/4" (83.6 x 83.2 cm)
# CreditLine                                Larry Aldrich Foundation Fund
# AccessionNumber                                                105.1965
# Classification                                                Sculpture
# Department                                         Painting & Sculpture
# DateAcquired                                                 1965-03-09
# Cataloged                                                             Y
# ObjectID                                                          78798
# URL                          http://www.moma.org/collection/works/78798
# ThumbnailURL          http://www.moma.org/media/W1siZiIsIjIwODIwOCJd...
# Circumference (cm)                                                  NaN
# Depth (cm)                                                          NaN
# Diameter (cm)                                                       NaN
# Height (cm)                                                        83.6
# Length (cm)                                                         NaN
# Weight (kg)                                                         NaN
# Width (cm)                                                         83.2
# Seat Height (cm)                                                    NaN
# Duration (sec.)                                                     NaN
# Name: 73418, dtype: object

# %%
# Reference multiple rows by index label (in this case the index label 0 through 2)
# Returns a DataFrame
paintings_csv.loc[0:2]
# Out:
#                         Title     Artist ConstituentID  \
# 0          Rope and People, I  Joan Miró          4016
# 1         Fire in the Evening  Paul Klee          3130
# 2  Portrait of an Equilibrist  Paul Klee          3130
#
#                         Date  \
# 0  Barcelona, March 27, 1935
# 1                       1929
# 2                       1927
#
#                                               Medium  \
# 0  Oil on cardboard mounted on wood, with coil of...
# 1                                   Oil on cardboard
# 2  Oil and collage on cardboard over wood with pa...
#
#                            Dimensions  \
# 0  41 1/4 x 29 3/8" (104.8 x 74.6 cm)
# 1   13 3/8 x 13 1/4" (33.8 x 33.3 cm)
# 2     24 7/8 x 15 3/4" (63.2 x 40 cm)
#
#                                 CreditLine AccessionNumber Classification  \
# 0       Gift of the Pierre Matisse Gallery         71.1936       Painting
# 1  Mr. and Mrs. Joachim Jean Aberbach Fund        153.1970       Painting
# 2               Mrs. Simon Guggenheim Fund        195.1966       Painting
#
#              Department  ...  \
# 0  Painting & Sculpture  ...
# 1  Painting & Sculpture  ...
# 2  Painting & Sculpture  ...
#
#                                         ThumbnailURL Circumference (cm)  \
# 0  http://www.moma.org/media/W1siZiIsIjE2MDU0NiJd...                NaN
# 1  http://www.moma.org/media/W1siZiIsIjE3Njc2NyJd...                NaN
# 2  http://www.moma.org/media/W1siZiIsIjE3OTI4NSJd...                NaN
#
#    Depth (cm) Diameter (cm) Height (cm)  Length (cm)  Weight (kg)  Width (cm)  \
# 0         NaN           NaN       104.8          NaN          NaN        74.6
# 1         NaN           NaN        33.8          NaN          NaN        33.3
# 2         NaN           NaN        60.3          NaN          NaN        36.8
#
#    Seat Height (cm)  Duration (sec.)
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
#
# [3 rows x 24 columns]

# %%
# Reference a row or multiple rows by zero-based integer position

# Access first row of paintings_csv by row integer value
# In this case the row is row 0
paintings_csv.iloc[0]

# Access first row of sculptures_json by row integer value
# In this case the row is also row 0
sculptures_json.iloc[0]
# Out:
# Title                                    Surface with Vibrating Texture
# Artist                                                  Getulio Alviani
# ConstituentID                                                       137
# Date                                                               1964
# Medium                                        Brushed aluminum on board
# Dimensions                                33 x 32 3/4" (83.6 x 83.2 cm)
# CreditLine                                Larry Aldrich Foundation Fund
# AccessionNumber                                                105.1965
# Classification                                                Sculpture
# Department                                         Painting & Sculpture
# DateAcquired                                                 1965-03-09
# Cataloged                                                             Y
# ObjectID                                                          78798
# URL                          http://www.moma.org/collection/works/78798
# ThumbnailURL          http://www.moma.org/media/W1siZiIsIjIwODIwOCJd...
# Circumference (cm)                                                  NaN
# Depth (cm)                                                          NaN
# Diameter (cm)                                                       NaN
# Height (cm)                                                        83.6
# Length (cm)                                                         NaN
# Weight (kg)                                                         NaN
# Width (cm)                                                         83.2
# Seat Height (cm)                                                    NaN
# Duration (sec.)                                                     NaN
# Name: 73418, dtype: object

# %%
# Reference multiple rows by row number (in this case rows 0 through 2)
# Note that this time the range doesn't include the stop number
paintings_csv.iloc[0:3]
# Out:
#                         Title     Artist ConstituentID  \
# 0          Rope and People, I  Joan Miró          4016
# 1         Fire in the Evening  Paul Klee          3130
# 2  Portrait of an Equilibrist  Paul Klee          3130
#
#                         Date  \
# 0  Barcelona, March 27, 1935
# 1                       1929
# 2                       1927
#
#                                               Medium  \
# 0  Oil on cardboard mounted on wood, with coil of...
# 1                                   Oil on cardboard
# 2  Oil and collage on cardboard over wood with pa...
#
#                            Dimensions  \
# 0  41 1/4 x 29 3/8" (104.8 x 74.6 cm)
# 1   13 3/8 x 13 1/4" (33.8 x 33.3 cm)
# 2     24 7/8 x 15 3/4" (63.2 x 40 cm)
#
#                                 CreditLine AccessionNumber Classification  \
# 0       Gift of the Pierre Matisse Gallery         71.1936       Painting
# 1  Mr. and Mrs. Joachim Jean Aberbach Fund        153.1970       Painting
# 2               Mrs. Simon Guggenheim Fund        195.1966       Painting
#
#              Department  ...  \
# 0  Painting & Sculpture  ...
# 1  Painting & Sculpture  ...
# 2  Painting & Sculpture  ...
#
#                                         ThumbnailURL Circumference (cm)  \
# 0  http://www.moma.org/media/W1siZiIsIjE2MDU0NiJd...                NaN
# 1  http://www.moma.org/media/W1siZiIsIjE3Njc2NyJd...                NaN
# 2  http://www.moma.org/media/W1siZiIsIjE3OTI4NSJd...                NaN
#
#    Depth (cm) Diameter (cm) Height (cm)  Length (cm)  Weight (kg)  Width (cm)  \
# 0         NaN           NaN       104.8          NaN          NaN        74.6
# 1         NaN           NaN        33.8          NaN          NaN        33.3
# 2         NaN           NaN        60.3          NaN          NaN        36.8
#
#    Seat Height (cm)  Duration (sec.)
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
#
# [3 rows x 24 columns]

# %% [markdown]
# Referencing Columns

# %%
# Referencing a column by column label (in this case, "Medium")
paintings_csv['Medium']
# Out:
# 0       Oil on cardboard mounted on wood, with coil of...
# 1                                        Oil on cardboard
# 2       Oil and collage on cardboard over wood with pa...
# 3                Oil, charcoal and pinned paper on canvas
# 4       Shingles, needlepoint, page from Concordance, ...
#                               ...
# 2355    Oil, pencil, and gold leaf on two joined canvases
# 2356    Oil, pencil, and gold leaf on two joined canvases
# 2357    Acrylic, paper pulp, cut and pasted fabrics, a...
# 2358    Acrylic and lacquer on linen with cotton and a...
# 2359                                        Oil on canvas
# Name: Medium, Length: 2360, dtype: object

# %%
# Referencing multiple columns by a list of column labels 
# (in this case, the columns "Medium" and "Dimensions")
paintings_csv[['Medium', 'Dimensions']]
# Out:
#                                                  Medium  \
# 0     Oil on cardboard mounted on wood, with coil of...
# 1                                      Oil on cardboard
# 2     Oil and collage on cardboard over wood with pa...
# 3              Oil, charcoal and pinned paper on canvas
# 4     Shingles, needlepoint, page from Concordance, ...
# ...                                                 ...
# 2355  Oil, pencil, and gold leaf on two joined canvases
# 2356  Oil, pencil, and gold leaf on two joined canvases
# 2357  Acrylic, paper pulp, cut and pasted fabrics, a...
# 2358  Acrylic and lacquer on linen with cotton and a...
# 2359                                      Oil on canvas
#
#                                              Dimensions
# 0                    41 1/4 x 29 3/8" (104.8 x 74.6 cm)
# 1                     13 3/8 x 13 1/4" (33.8 x 33.3 cm)
# 2                       24 7/8 x 15 3/4" (63.2 x 40 cm)
# 3                           7' 1" x 31" (216 x 78.8 cm)
# 4                         20 x 21 1/4" (50.8 x 54.0 cm)
# ...                                                 ...
# 2355          24 × 17 3/4" (61 × 45.1 cm), in two parts
# 2356          24 × 17 3/4" (61 × 45.1 cm), in two parts
# 2357  118 1/4 × 165 1/2 × 3 3/4" (300.4 × 420.4 × 9....
# 2358                        54 × 44" (137.2 × 111.8 cm)
# 2359                        65 × 65" (165.1 × 165.1 cm)
#
# [2360 rows x 2 columns]

# %% [markdown]
# Referencing both rows and columns

# %%
# Referencing a subset of rows and columns using index and column labels
# Note that we're using a range of column labels instead of a list
# Make sure that your column range starts with the leftmost label
paintings_csv.loc[:9, 'Title':'Medium']
# Out:
#                         Title             Artist ConstituentID  \
# 0          Rope and People, I          Joan Miró          4016
# 1         Fire in the Evening          Paul Klee          3130
# 2  Portrait of an Equilibrist          Paul Klee          3130
# 3                      Guitar      Pablo Picasso          4609
# 4                 Grandmother        Arthur Dove          1602
# 5                "M'Amenez-y"    Francis Picabia          4607
# 6                    Untitled     Blinky Palermo          4474
# 7       Daylight Savings Time         Pierre Roy          5065
# 8                  The Bather       Paul Cézanne          1053
# 9         Syntheses of Naples  Enrico Prampolini          4720
#
#                                   Date  \
# 0            Barcelona, March 27, 1935
# 1                                 1929
# 2                                 1927
# 3                    Paris, early 1919
# 4                                 1925
# 5  Paris, November 1919 - January 1920
# 6                                 1970
# 7                                 1929
# 8                              c. 1885
# 9                          before 1930
#
#                                               Medium
# 0  Oil on cardboard mounted on wood, with coil of...
# 1                                   Oil on cardboard
# 2  Oil and collage on cardboard over wood with pa...
# 3           Oil, charcoal and pinned paper on canvas
# 4  Shingles, needlepoint, page from Concordance, ...
# 5                  Oil and enamel paint on cardboard
# 6                      Dyed cotton mounted on muslin
# 7                                      Oil on canvas
# 8                                      Oil on canvas
# 9                                      Oil on canvas

# %% [markdown]
# ### Writing data to a file

# %%
# Save the subset from the previous cell in a variable
first_ten = paintings_csv.loc[:9, 'Title':'Medium']

# Write to csv
first_ten.to_csv("new_data.csv")

# %%
#Write to an Excel file
first_ten.to_excel("new_data.xls")

# %%
# Write to a JSON file
first_ten.to_json("new_data.json")

# %% [markdown]
# ----
# ## Open work time
# You can use this time to ask questions, collaborate, or work on the following activities (on your own or in a group).

# %% [markdown]
# ### Exercise 1: Read in an Excel file
# Take this Excel file, read it into a DataFrame, and print out the first five rows of the DataFrame.
#
#
#
# > Hint: the syntax is very similar to reading a .csv file.
#
#
#
# Link to the file: https://github.com/ncsu-libraries-data-vis/teaching-datasets/blob/main/moma_data/moma_photographs.xlsx?raw=true

# %%
# Save the url as a variable
xls_file_url = 'https://github.com/ncsu-libraries-data-vis/teaching-datasets/blob/main/moma_data/moma_photographs.xlsx?raw=true'

# Read the file in
photographs_xls = pd.read_excel(xls_file_url)

# View the file
photographs_xls.head()
# Out:
#                                     Title        Artist ConstituentID  \
# 0             Untitled from VVV Portfolio    David Hare          2504
# 1  Tuileries Sanglier / d'apres l'antique  Eugène Atget           229
# 2                         Sapin (Trianon)  Eugène Atget           229
# 3             Versailles, vase par Ballin  Eugène Atget           229
# 4                                 Facteur  Eugène Atget           229
#
#                       Date                                             Medium  \
# 0  c. 1941, published 1943  Gelatin silver print mounted on paper from a p...
# 1                     1911                               Albumen silver print
# 2                  1910-14                               Albumen silver print
# 3                     1902                         Matte albumen silver print
# 4                1899-1900            Gelatin silver printing-out-paper print
#
#                                           Dimensions  \
# 0  composition: 12 x 9 3/4" (30.5 x 24.8 cm); she...
# 1                   8 11/16 × 6 9/16" (22 × 16.7 cm)
# 2            Approx. 7 1/8 × 8 5/8" (18.1 × 21.9 cm)
# 3            Approx. 8 9/16 × 7 1/16" (21.8 × 18 cm)
# 4           Approx. 8 11/16 × 6 9/16" (22 × 16.7 cm)
#
#                                           CreditLine AccessionNumber  \
# 0                      The Louis E. Stern Collection     1113.1964.6
# 1  Abbott-Levy Collection. Partial gift of Shirle...        1.1969.1
# 2  Abbott-Levy Collection. Partial gift of Shirle...       1.1969.10
# 3  Abbott-Levy Collection. Partial gift of Shirle...      1.1969.100
# 4  Abbott-Levy Collection. Partial gift of Shirle...     1.1969.1000
#
#   Classification         Department  ...  \
# 0     Photograph  Drawings & Prints  ...
# 1     Photograph        Photography  ...
# 2     Photograph        Photography  ...
# 3     Photograph        Photography  ...
# 4     Photograph        Photography  ...
#
#                                         ThumbnailURL Circumference (cm)  \
# 0  http://www.moma.org/media/W1siZiIsIjM0NTUzOCJd...                NaN
# 1  http://www.moma.org/media/W1siZiIsIjMwMTMwNCJd...                NaN
# 2  http://www.moma.org/media/W1siZiIsIjMxODEwMSJd...                NaN
# 3  http://www.moma.org/media/W1siZiIsIjMxODEwMiJd...                NaN
# 4  http://www.moma.org/media/W1siZiIsIjI4NjE4MiJd...                NaN
#
#    Depth (cm) Diameter (cm) Height (cm)  Length (cm)  Weight (kg)  Width (cm)  \
# 0         NaN           NaN        30.5          NaN          NaN        24.8
# 1         NaN           NaN         NaN          NaN          NaN         NaN
# 2         NaN           NaN         NaN          NaN          NaN         NaN
# 3         NaN           NaN         NaN          NaN          NaN         NaN
# 4         NaN           NaN         NaN          NaN          NaN         NaN
#
#    Seat Height (cm)  Duration (sec.)
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Exercise 2: Indexing cells
#
# Use referencing and indexing to answer the following questions by finding the data in the rows, columns, and/or cells.

# %% [markdown]
# #### 2a. Titles
# Create a `Series` of the title of each piece of artwork. (`Titles`)

# %%
# 2a. Create a `Series` of the titles (`Title`)
titles = paintings_csv['Title']

# Print new Series
titles
# Out:
# 0               Rope and People, I
# 1              Fire in the Evening
# 2       Portrait of an Equilibrist
# 3                           Guitar
# 4                      Grandmother
#                    ...
# 2355                  Zacimba Gaba
# 2356                         Zumbi
# 2357                    Vertigo #2
# 2358          Lot 111113 (flare 1)
# 2359             Unknown Pleasures
# Name: Title, Length: 2360, dtype: object

# %% [markdown]
# #### 2b. Date and time
# We want to compare artists with their medium of choice. Which artists used which mediums? Print the columns from the data for the artist, the date of the artwork, and the medium (`Artist`, `Date`, and `Medium`).

# %%
# 2b. Print the columns from the data for the artist, the date of the artwork, and the medium
# (`Artist`, `Date`, and `Medium`)
paintings_csv[["Artist", "Date", "Medium"]]
# Out:
#               Artist                       Date  \
# 0          Joan Miró  Barcelona, March 27, 1935
# 1          Paul Klee                       1929
# 2          Paul Klee                       1927
# 3      Pablo Picasso          Paris, early 1919
# 4        Arthur Dove                       1925
# ...              ...                        ...
# 2355    Dalton Paula                       2020
# 2356    Dalton Paula                       2020
# 2357  Ouattara Watts                       2011
# 2358  Donald Moffett                       2013
# 2359    Matthew Wong                       2019
#
#                                                  Medium
# 0     Oil on cardboard mounted on wood, with coil of...
# 1                                      Oil on cardboard
# 2     Oil and collage on cardboard over wood with pa...
# 3              Oil, charcoal and pinned paper on canvas
# 4     Shingles, needlepoint, page from Concordance, ...
# ...                                                 ...
# 2355  Oil, pencil, and gold leaf on two joined canvases
# 2356  Oil, pencil, and gold leaf on two joined canvases
# 2357  Acrylic, paper pulp, cut and pasted fabrics, a...
# 2358  Acrylic and lacquer on linen with cotton and a...
# 2359                                      Oil on canvas
#
# [2360 rows x 3 columns]

# %% [markdown]
# #### 2c. Access the 124th row
#
# Use row indexing to find the data in the 124th row in the `sculptures_json` DataFrame. Check that your result is correct by making sure the `Title` value is `Untitled (Tangle)`.
#
# > Tip: Remember that the integer-based row location is zero based

# %%
# 2c. Access the 124th row from the 'sculptures_json` DataFrame
sculptures_json.iloc[123]
# Out:
# Title                                                 Untitled (Tangle)
# Artist                                                    Robert Morris
# ConstituentID                                                      4108
# Date                                                               1967
# Medium                                                             Felt
# Dimensions            Dimensions variable, approximately 9' 8" x 8' ...
# CreditLine                                       Gift of Philip Johnson
# AccessionNumber                                                 64.1995
# Classification                                                Sculpture
# Department                                         Painting & Sculpture
# DateAcquired                                                 1995-02-06
# Cataloged                                                             Y
# ObjectID                                                          80888
# URL                          http://www.moma.org/collection/works/80888
# ThumbnailURL          http://www.moma.org/media/W1siZiIsIjQ3NzIxMSJd...
# Circumference (cm)                                                  NaN
# Depth (cm)                                                        147.3
# Diameter (cm)                                                       NaN
# Height (cm)                                                       294.6
# Length (cm)                                                         NaN
# Weight (kg)                                                         NaN
# Width (cm)                                                        269.2
# Seat Height (cm)                                                    NaN
# Duration (sec.)                                                     NaN
# Name: 74935, dtype: object

# %% [markdown]
# #### 2d. Jacob Lawrence exhibit dimensions
# To set up for an exhibit of Jacob Lawrence's work, the curators need to see which items will fit in the space. Print rows 173-178 and the columns `Artist`, `Medium`, `Height (cm)`,`Width (cm)` from the .csv file containing paintings data.

# %%
# 2d. Print rows 173-178 and the columns `Artist`, `Medium`, `Height (cm)`,`Width (cm)`.
exhibit = paintings_csv.loc[173:178, ['Artist', 'Medium', 'Height (cm)','Width (cm)']]
exhibit
# Out:
#              Artist                       Medium  Height (cm)  Width (cm)
# 173  Jacob Lawrence  Casein tempera on hardboard    30.480061   45.720091
# 174  Jacob Lawrence  Casein tempera on hardboard    30.480061   45.720091
# 175  Jacob Lawrence  Casein tempera on hardboard    45.720091   30.480061
# 176  Jacob Lawrence  Casein tempera on hardboard    45.720091   30.480061
# 177  Jacob Lawrence  Casein tempera on hardboard    30.480061   45.720091
# 178  Jacob Lawrence  Casein tempera on hardboard    30.500000   45.700000

# %% [markdown]
# ### Exercise 3: Write to a file
# Take the your result in exercise 2d. (or another DataFrame you have created), and write it to a .csv file.

# %%
# Write to a new .csv file
exhibit.to_csv("exercise3.csv")

# %% [markdown]
# ## Further resources
#
# ### Unfilled version of this notebook
#
# [Python Open Labs Week 1 unfilled notebook](https://colab.research.google.com/github/ncsu-libraries-data-vis/python-open-labs/blob/main/Open_Lab_1_reading_exploring_and_writing_data_with_pandas/Open_Lab_1_reading_exploring_and_writing_data_with_pandas.ipynb) - a version of this notebook with all code removed for the guided activity and exercises, contains empty code blocks with prompts.
#
# ### Learning resources
#
# - [Python Data Science Handbook](https://jakevdp.github.io/PythonDataScienceHandbook/index.html) - a free, online version of Jake VanderPlas' introduction to data science with Python, includes a chapter on data manipulation with pandas.
# - [Python Programming for Data Science](https://www.tomasbeuzen.com/python-programming-for-data-science/README.html) - a website providing a great overview of conducting data science with Python including pandas.
# - [Real Python](https://realpython.com/) contains a lot of different tutorials at different levels
# - [LinkedIn Learning](https://www.lynda.com/Python-training-tutorials/415-0.html) is free with NC State accounts and contains several video series for learning Python
# - [Dataquest](https://www.dataquest.io/) is a free then paid series of courses with an emphasis on data science
#
# ### Finding help with pandas
#
# The [Pandas website](https://pandas.pydata.org/) and [online documentation](http://pandas.pydata.org/pandas-docs/stable/) are useful resources, and of course the indispensible [Stack Overflow has a "pandas" tag](https://stackoverflow.com/questions/tagged/pandas).  There is also a (much younger, much smaller) [sister site dedicated to Data Science questions that has a "pandas" tag](https://datascience.stackexchange.com/questions/tagged/pandas) too.

# %% [markdown]
# ## Evaluation Survey
# Please, spend 1 minute answering these questions that help improve future workshops.
#
# https://go.ncsu.edu/dvs-eval

# %% [markdown]
# ## Credits
#
# This workshop was created by Claire Cahoon and Walt Gurley, adapted from previous workshop materials by Scott Bailey and Simon Wiles, of Stanford Libraries.

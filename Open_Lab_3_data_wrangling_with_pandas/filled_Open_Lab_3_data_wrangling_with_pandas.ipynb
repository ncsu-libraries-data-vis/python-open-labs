# %% [markdown]
# # Python Open Labs: Data wrangling with pandas
#
# ## Setup
#
# With this Google Colaboratory (Colab) notebook open, click the "Copy to Drive" button that appears in the menu bar. The notebook will then be attached to your own user account, so you can edit it in any way you like -- you can even take notes directly in the notebook.
#
# ## Open Labs agenda
#
# 1. **Guided activity**: One of the instructors will share their screen to work through the guided activity and teach concepts along the way.
#
# 2. **Open lab time**: After the guided portion of the Open Lab, the rest of the time is for you to ask questions, work collaboratively, or have self-guided practice time. You will have access to instructors and peers for questions and support.
#
# ## Learning objectives
#
# By the end of our workshop today, we hope you'll understand basic pandas methods for normalizing values, modifying data, dealing with missing data, and working with strings and dates.
#
# ## Today's Topics
#
# - Replacing values in a DataFrame column
# - Creating new columns using expressions
# - Creating new columns with functions
# - Dealing with missing values
# - Working with string data
# - Working with dates
#
# ## Questions during the workshop
#
# Please feel free to ask questions throughout the workshop.
#
# We have a second instructor who will available during the workshop. They will answer as able, and will collect questions with answers that might help everyone to be answered at the end of the workshop.
#
# The open lab time is when you will be able to ask more questions and work together on the exercises.

# %% [markdown]
# ## Guided Instruction
#
# In this Open Lab we're introducing how to use the pandas library to "wrangle" data; or clean, manipulate, and prepare datasets for analysis.
#
# In this section, we will work through examples using data from the [Museum of Modern Art (MoMA) research dataset](https://github.com/MuseumofModernArt/collection) containing records of all of the works that have been cataloged in the database of the MoMA collection.
#
# > "The Museum’s website features 89,695 artworks from 26,494 artists. This research dataset contains 138,151 records, representing all of the works that have been accessioned into MoMA’s collection and cataloged in our database. It includes basic metadata for each work, including title, artist, date made, medium, dimensions, and date acquired by the Museum. Some of these records have incomplete information and are noted as “not Curator Approved." - [MoMA Github repository for collection data](https://github.com/MuseumofModernArt/collection)
#
# We have prepared a dataset that consists of a subset of MoMA artworks classified as paintings and their associated artist information to use in the following activities. We will be referencing the data that we have prepared in our [Github repository for teaching datasets](https://github.com/ncsu-libraries-data-vis/teaching-datasets/tree/main/moma_data).

# %%
# Import the Pandas library as pd (callable in our code as pd)
import pandas as pd

# %% [markdown]
# ### Load the dataset

# %%
# Import the MoMA paintings with artist information dataset (CSV file)
# The file location
file_url = 'https://raw.githubusercontent.com/ncsu-libraries-data-vis/teaching-datasets/main/moma_data/moma_paintings_full.csv'

# Read in the file and print out the DataFrame
paintings = pd.read_csv(file_url)
paintings
# Out:
#                             Title          Artist  ConstituentID  \
# 1              Rope and People, I       Joan Miró         4016.0
# 2             Fire in the Evening       Paul Klee         3130.0
# 3      Portrait of an Equilibrist       Paul Klee         3130.0
# 4                          Guitar   Pablo Picasso         4609.0
# 5                     Grandmother     Arthur Dove         1602.0
# ...                           ...             ...            ...
# 38098                Zacimba Gaba    Dalton Paula       132719.0
# 38099                       Zumbi    Dalton Paula       132719.0
# 38100                  Vertigo #2  Ouattara Watts       132954.0
# 38101        Lot 111113 (flare 1)  Donald Moffett         7435.0
# 38102           Unknown Pleasures    Matthew Wong       132956.0
#
#                             Date  \
# 1      Barcelona, March 27, 1935
# 2                           1929
# 3                           1927
# 4              Paris, early 1919
# 5                           1925
# ...                          ...
# 38098                       2020
# 38099                       2020
# 38100                       2011
# 38101                       2013
# 38102                       2019
#
#                                                   Medium  \
# 1      Oil on cardboard mounted on wood, with coil of...
# 2                                       Oil on cardboard
# 3      Oil and collage on cardboard over wood with pa...
# 4               Oil, charcoal and pinned paper on canvas
# 5      Shingles, needlepoint, page from Concordance, ...
# ...                                                  ...
# 38098  Oil, pencil, and gold leaf on two joined canvases
# 38099  Oil, pencil, and gold leaf on two joined canvases
# 38100  Acrylic, paper pulp, cut and pasted fabrics, a...
# 38101  Acrylic and lacquer on linen with cotton and a...
# 38102                                      Oil on canvas
#
#                                               Dimensions  \
# 1                     41 1/4 x 29 3/8" (104.8 x 74.6 cm)
# 2                      13 3/8 x 13 1/4" (33.8 x 33.3 cm)
# 3                        24 7/8 x 15 3/4" (63.2 x 40 cm)
# 4                            7' 1" x 31" (216 x 78.8 cm)
# 5                          20 x 21 1/4" (50.8 x 54.0 cm)
# ...                                                  ...
# 38098          24 × 17 3/4" (61 × 45.1 cm), in two parts
# 38099          24 × 17 3/4" (61 × 45.1 cm), in two parts
# 38100  118 1/4 × 165 1/2 × 3 3/4" (300.4 × 420.4 × 9....
# 38101                        54 × 44" (137.2 × 111.8 cm)
# 38102                        65 × 65" (165.1 × 165.1 cm)
#
#                                     CreditLine AccessionNumber Classification  \
# 1           Gift of the Pierre Matisse Gallery         71.1936       Painting
# 2      Mr. and Mrs. Joachim Jean Aberbach Fund        153.1970       Painting
# 3                   Mrs. Simon Guggenheim Fund        195.1966       Painting
# 4                   Gift of A. Conger Goodyear        384.1955       Painting
# 5      Gift of Philip L. Goodwin (by exchange)        636.1939       Painting
# ...                                        ...             ...            ...
# 38098                                      NaN       TR16514.1       Painting
# 38099                                      NaN       TR16514.2       Painting
# 38100                                      NaN         TR16516       Painting
# 38101                                      NaN         TR16517       Painting
# 38102                                      NaN         TR16518       Painting
#
#                  Department  ... Height (cm) Length (cm)  Weight (kg)  \
# 1      Painting & Sculpture  ...  104.800000         NaN          NaN
# 2      Painting & Sculpture  ...   33.800000         NaN          NaN
# 3      Painting & Sculpture  ...   60.300000         NaN          NaN
# 4      Painting & Sculpture  ...  215.900000         NaN          NaN
# 5      Painting & Sculpture  ...   50.800000         NaN          NaN
# ...                     ...  ...         ...         ...          ...
# 38098  Painting & Sculpture  ...   60.960122         NaN          NaN
# 38099  Painting & Sculpture  ...   60.960122         NaN          NaN
# 38100  Painting & Sculpture  ...  300.355601         NaN          NaN
# 38101  Painting & Sculpture  ...  137.160274         NaN          NaN
# 38102  Painting & Sculpture  ...  165.100330         NaN          NaN
#
#        Width (cm)  Duration (sec.)                            ArtistBio  \
# 1       74.600000              NaN                   Spanish, 1893–1983
# 2       33.300000              NaN  German, born Switzerland. 1879–1940
# 3       36.800000              NaN  German, born Switzerland. 1879–1940
# 4       78.700000              NaN                   Spanish, 1881–1973
# 5       54.000000              NaN                  American, 1880–1946
# ...           ...              ...                                  ...
# 38098   45.085090              NaN                 Brazilian, born 1982
# 38099   45.085090              NaN                 Brazilian, born 1982
# 38100  420.370841              NaN     American, born Ivory Coast, 1957
# 38101  111.760224              NaN                  American, born 1955
# 38102  165.100330              NaN                Canadian, 1984 - 2019
#
#        Nationality  Gender  BeginDate  EndDate
# 1          Spanish    Male     1893.0   1983.0
# 2           German    Male     1879.0   1940.0
# 3           German    Male     1879.0   1940.0
# 4          Spanish    Male     1881.0   1973.0
# 5         American    Male     1880.0   1946.0
# ...            ...     ...        ...      ...
# 38098    Brazilian     NaN     1982.0      0.0
# 38099    Brazilian     NaN     1982.0      0.0
# 38100     American     NaN     1957.0      0.0
# 38101     American    Male     1955.0      0.0
# 38102          NaN     NaN        0.0      0.0
#
# [2350 rows x 26 columns]

# %%
# Observe a summary of the DataFrame columns using the DataFrame method info()
paintings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2350 entries, 1 to 38102
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               2350 non-null   object
#  1   Artist              2349 non-null   object
#  2   ConstituentID       2349 non-null   float64
#  3   Date                2343 non-null   object
#  4   Medium              2349 non-null   object
#  5   Dimensions          2345 non-null   object
#  6   CreditLine          2343 non-null   object
#  7   AccessionNumber     2350 non-null   object
#  8   Classification      2350 non-null   object
#  9   Department          2350 non-null   object
#  10  DateAcquired        2340 non-null   object
#  11  Cataloged           2350 non-null   object
#  12  ObjectID            2350 non-null   int64
#  13  Circumference (cm)  0 non-null      float64
#  14  Depth (cm)          403 non-null    float64
#  15  Diameter (cm)       12 non-null     float64
#  16  Height (cm)         2320 non-null   float64
#  17  Length (cm)         0 non-null      float64
#  18  Weight (kg)         3 non-null      float64
#  19  Width (cm)          2317 non-null   float64
#  20  Duration (sec.)     0 non-null      float64
#  21  ArtistBio           2348 non-null   object
#  22  Nationality         2347 non-null   object
#  23  Gender              2339 non-null   object
#  24  BeginDate           2349 non-null   float64
#  25  EndDate             2349 non-null   float64
# dtypes: float64(11), int64(1), object(14)
# memory usage: 495.7+ KB

# %% [markdown]
# ### Replacing values in a column
#
# We can replace values in a column by first accessing the column and using the Series method `replace()` (*remember accessing one column from a DataFrame returns a pandas Series*). The `replace()` method can accept a dictionary of items in which the dictionary keys are the values to be replaced and the dictionary values are the new values to be inserted.
#
# We will demonstrate this method by replacing the values `Y` and `N` in the `Cataloged` column to the more explicit values `Yes` and `No`, respectively. Also, we will edit the DataFrame directly by including the keyword argument `inplace=True`.

# %%
# Print the unique values contained in the "Cataloged" column using the
# DataFrame method unique()
paintings['Cataloged'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
# Replace the values "Y" and "N" in the "Cataloged" column with "Yes" and "No"
paintings['Cataloged'].replace({'Y': 'Yes', 'N': 'No'}, inplace=True)

# Print out the unique values of the "Cataloged" column
paintings['Cataloged'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# ### Creating a new column using an expression
#
# We can create new columns of data on an existing DataFrame and assign values calculated from existing columns of data. This is done by first calling the index of the new column (for example, `df['NEW_COLUMN_NAME']`) and assigning the new column the results of some expression that can include existing columns of data from the DataFrame.
#
# We will create a new column named `Area (cm^2)` that contains the centimeter squared area of a painting based on the values provided in the columns `Width (cm)` and `Height (cm)`.

# %%
# Create a new column "Area (cm^2)" containing the size of a painting based
# on the width and height value of the painting
paintings['Area (cm^2)'] = paintings['Width (cm)'] * paintings['Height (cm)']

# Print out the full DataFrame
paintings
# Out:
#                             Title          Artist  ConstituentID  \
# 1              Rope and People, I       Joan Miró         4016.0
# 2             Fire in the Evening       Paul Klee         3130.0
# 3      Portrait of an Equilibrist       Paul Klee         3130.0
# 4                          Guitar   Pablo Picasso         4609.0
# 5                     Grandmother     Arthur Dove         1602.0
# ...                           ...             ...            ...
# 38098                Zacimba Gaba    Dalton Paula       132719.0
# 38099                       Zumbi    Dalton Paula       132719.0
# 38100                  Vertigo #2  Ouattara Watts       132954.0
# 38101        Lot 111113 (flare 1)  Donald Moffett         7435.0
# 38102           Unknown Pleasures    Matthew Wong       132956.0
#
#                             Date  \
# 1      Barcelona, March 27, 1935
# 2                           1929
# 3                           1927
# 4              Paris, early 1919
# 5                           1925
# ...                          ...
# 38098                       2020
# 38099                       2020
# 38100                       2011
# 38101                       2013
# 38102                       2019
#
#                                                   Medium  \
# 1      Oil on cardboard mounted on wood, with coil of...
# 2                                       Oil on cardboard
# 3      Oil and collage on cardboard over wood with pa...
# 4               Oil, charcoal and pinned paper on canvas
# 5      Shingles, needlepoint, page from Concordance, ...
# ...                                                  ...
# 38098  Oil, pencil, and gold leaf on two joined canvases
# 38099  Oil, pencil, and gold leaf on two joined canvases
# 38100  Acrylic, paper pulp, cut and pasted fabrics, a...
# 38101  Acrylic and lacquer on linen with cotton and a...
# 38102                                      Oil on canvas
#
#                                               Dimensions  \
# 1                     41 1/4 x 29 3/8" (104.8 x 74.6 cm)
# 2                      13 3/8 x 13 1/4" (33.8 x 33.3 cm)
# 3                        24 7/8 x 15 3/4" (63.2 x 40 cm)
# 4                            7' 1" x 31" (216 x 78.8 cm)
# 5                          20 x 21 1/4" (50.8 x 54.0 cm)
# ...                                                  ...
# 38098          24 × 17 3/4" (61 × 45.1 cm), in two parts
# 38099          24 × 17 3/4" (61 × 45.1 cm), in two parts
# 38100  118 1/4 × 165 1/2 × 3 3/4" (300.4 × 420.4 × 9....
# 38101                        54 × 44" (137.2 × 111.8 cm)
# 38102                        65 × 65" (165.1 × 165.1 cm)
#
#                                     CreditLine AccessionNumber Classification  \
# 1           Gift of the Pierre Matisse Gallery         71.1936       Painting
# 2      Mr. and Mrs. Joachim Jean Aberbach Fund        153.1970       Painting
# 3                   Mrs. Simon Guggenheim Fund        195.1966       Painting
# 4                   Gift of A. Conger Goodyear        384.1955       Painting
# 5      Gift of Philip L. Goodwin (by exchange)        636.1939       Painting
# ...                                        ...             ...            ...
# 38098                                      NaN       TR16514.1       Painting
# 38099                                      NaN       TR16514.2       Painting
# 38100                                      NaN         TR16516       Painting
# 38101                                      NaN         TR16517       Painting
# 38102                                      NaN         TR16518       Painting
#
#                  Department  ... Length (cm) Weight (kg)  Width (cm)  \
# 1      Painting & Sculpture  ...         NaN         NaN   74.600000
# 2      Painting & Sculpture  ...         NaN         NaN   33.300000
# 3      Painting & Sculpture  ...         NaN         NaN   36.800000
# 4      Painting & Sculpture  ...         NaN         NaN   78.700000
# 5      Painting & Sculpture  ...         NaN         NaN   54.000000
# ...                     ...  ...         ...         ...         ...
# 38098  Painting & Sculpture  ...         NaN         NaN   45.085090
# 38099  Painting & Sculpture  ...         NaN         NaN   45.085090
# 38100  Painting & Sculpture  ...         NaN         NaN  420.370841
# 38101  Painting & Sculpture  ...         NaN         NaN  111.760224
# 38102  Painting & Sculpture  ...         NaN         NaN  165.100330
#
#        Duration (sec.)                            ArtistBio  Nationality  \
# 1                  NaN                   Spanish, 1893–1983      Spanish
# 2                  NaN  German, born Switzerland. 1879–1940       German
# 3                  NaN  German, born Switzerland. 1879–1940       German
# 4                  NaN                   Spanish, 1881–1973      Spanish
# 5                  NaN                  American, 1880–1946     American
# ...                ...                                  ...          ...
# 38098              NaN                 Brazilian, born 1982    Brazilian
# 38099              NaN                 Brazilian, born 1982    Brazilian
# 38100              NaN     American, born Ivory Coast, 1957     American
# 38101              NaN                  American, born 1955     American
# 38102              NaN                Canadian, 1984 - 2019          NaN
#
#        Gender  BeginDate  EndDate    Area (cm^2)
# 1        Male     1893.0   1983.0    7818.080000
# 2        Male     1879.0   1940.0    1125.540000
# 3        Male     1879.0   1940.0    2219.040000
# 4        Male     1881.0   1973.0   16991.330000
# 5        Male     1880.0   1946.0    2743.200000
# ...       ...        ...      ...            ...
# 38098     NaN     1982.0      0.0    2748.392594
# 38099     NaN     1982.0      0.0    2748.392594
# 38100     NaN     1957.0      0.0  126260.736392
# 38101    Male     1955.0      0.0   15329.062916
# 38102     NaN        0.0      0.0   27258.119032
#
# [2350 rows x 27 columns]

# %% [markdown]
# ### Creating a new column using apply
#
# Sometimes we need to create new data using more complex methods than a simple expression. We will create a new column named `OilPainting` to identify all painting that contain the word "oil" in their medium description (contained in the column `medium`). This cannot be reliably accomplished without doing some advanced manipulation of the medium description.
#
# We will use the Series method `apply()` to call the function `is_oil_based_painting`, which contains the necessary code to produce the desired results, on the column `Medium`.

# %%
# Return whether a painting is oil-based (Yes) or not (No) based on the
# occurrence of the word "oil" in the artwork medium description
def is_oil_based_painting(medium):
    # Test if value is a string (can't apply string methods on NaNs)
    if type(medium) == str:
        # Create a list of lowercase words, commas removed, from description
        description = medium.lower().replace(',', '').split(' ')
        # Test if "oil" is in list
        if 'oil' in description:
            return 'Yes'
        return 'No'

# Use the Series method apply to call the "is_oil_based_painting" function on
# the column "Medium"
paintings['OilPainting'] = paintings['Medium'].apply(
    is_oil_based_painting
)

# Print out the resulting DataFrame
paintings
# Out:
#                             Title          Artist  ConstituentID  \
# 1              Rope and People, I       Joan Miró         4016.0
# 2             Fire in the Evening       Paul Klee         3130.0
# 3      Portrait of an Equilibrist       Paul Klee         3130.0
# 4                          Guitar   Pablo Picasso         4609.0
# 5                     Grandmother     Arthur Dove         1602.0
# ...                           ...             ...            ...
# 38098                Zacimba Gaba    Dalton Paula       132719.0
# 38099                       Zumbi    Dalton Paula       132719.0
# 38100                  Vertigo #2  Ouattara Watts       132954.0
# 38101        Lot 111113 (flare 1)  Donald Moffett         7435.0
# 38102           Unknown Pleasures    Matthew Wong       132956.0
#
#                             Date  \
# 1      Barcelona, March 27, 1935
# 2                           1929
# 3                           1927
# 4              Paris, early 1919
# 5                           1925
# ...                          ...
# 38098                       2020
# 38099                       2020
# 38100                       2011
# 38101                       2013
# 38102                       2019
#
#                                                   Medium  \
# 1      Oil on cardboard mounted on wood, with coil of...
# 2                                       Oil on cardboard
# 3      Oil and collage on cardboard over wood with pa...
# 4               Oil, charcoal and pinned paper on canvas
# 5      Shingles, needlepoint, page from Concordance, ...
# ...                                                  ...
# 38098  Oil, pencil, and gold leaf on two joined canvases
# 38099  Oil, pencil, and gold leaf on two joined canvases
# 38100  Acrylic, paper pulp, cut and pasted fabrics, a...
# 38101  Acrylic and lacquer on linen with cotton and a...
# 38102                                      Oil on canvas
#
#                                               Dimensions  \
# 1                     41 1/4 x 29 3/8" (104.8 x 74.6 cm)
# 2                      13 3/8 x 13 1/4" (33.8 x 33.3 cm)
# 3                        24 7/8 x 15 3/4" (63.2 x 40 cm)
# 4                            7' 1" x 31" (216 x 78.8 cm)
# 5                          20 x 21 1/4" (50.8 x 54.0 cm)
# ...                                                  ...
# 38098          24 × 17 3/4" (61 × 45.1 cm), in two parts
# 38099          24 × 17 3/4" (61 × 45.1 cm), in two parts
# 38100  118 1/4 × 165 1/2 × 3 3/4" (300.4 × 420.4 × 9....
# 38101                        54 × 44" (137.2 × 111.8 cm)
# 38102                        65 × 65" (165.1 × 165.1 cm)
#
#                                     CreditLine AccessionNumber Classification  \
# 1           Gift of the Pierre Matisse Gallery         71.1936       Painting
# 2      Mr. and Mrs. Joachim Jean Aberbach Fund        153.1970       Painting
# 3                   Mrs. Simon Guggenheim Fund        195.1966       Painting
# 4                   Gift of A. Conger Goodyear        384.1955       Painting
# 5      Gift of Philip L. Goodwin (by exchange)        636.1939       Painting
# ...                                        ...             ...            ...
# 38098                                      NaN       TR16514.1       Painting
# 38099                                      NaN       TR16514.2       Painting
# 38100                                      NaN         TR16516       Painting
# 38101                                      NaN         TR16517       Painting
# 38102                                      NaN         TR16518       Painting
#
#                  Department  ... Weight (kg)  Width (cm)  Duration (sec.)  \
# 1      Painting & Sculpture  ...         NaN   74.600000              NaN
# 2      Painting & Sculpture  ...         NaN   33.300000              NaN
# 3      Painting & Sculpture  ...         NaN   36.800000              NaN
# 4      Painting & Sculpture  ...         NaN   78.700000              NaN
# 5      Painting & Sculpture  ...         NaN   54.000000              NaN
# ...                     ...  ...         ...         ...              ...
# 38098  Painting & Sculpture  ...         NaN   45.085090              NaN
# 38099  Painting & Sculpture  ...         NaN   45.085090              NaN
# 38100  Painting & Sculpture  ...         NaN  420.370841              NaN
# 38101  Painting & Sculpture  ...         NaN  111.760224              NaN
# 38102  Painting & Sculpture  ...         NaN  165.100330              NaN
#
#                                  ArtistBio  Nationality  Gender  BeginDate  \
# 1                       Spanish, 1893–1983      Spanish    Male     1893.0
# 2      German, born Switzerland. 1879–1940       German    Male     1879.0
# 3      German, born Switzerland. 1879–1940       German    Male     1879.0
# 4                       Spanish, 1881–1973      Spanish    Male     1881.0
# 5                      American, 1880–1946     American    Male     1880.0
# ...                                    ...          ...     ...        ...
# 38098                 Brazilian, born 1982    Brazilian     NaN     1982.0
# 38099                 Brazilian, born 1982    Brazilian     NaN     1982.0
# 38100     American, born Ivory Coast, 1957     American     NaN     1957.0
# 38101                  American, born 1955     American    Male     1955.0
# 38102                Canadian, 1984 - 2019          NaN     NaN        0.0
#
#        EndDate    Area (cm^2)  OilPainting
# 1       1983.0    7818.080000          Yes
# 2       1940.0    1125.540000          Yes
# 3       1940.0    2219.040000          Yes
# 4       1973.0   16991.330000          Yes
# 5       1946.0    2743.200000           No
# ...        ...            ...          ...
# 38098      0.0    2748.392594          Yes
# 38099      0.0    2748.392594          Yes
# 38100      0.0  126260.736392           No
# 38101      0.0   15329.062916           No
# 38102      0.0   27258.119032          Yes
#
# [2350 rows x 28 columns]

# %% [markdown]
# ### Removing missing data
#
# The MoMA paintings dataset contains many missing values. Missing values in a pandas are typically represented as `NaN`. We can handle missing values in several ways, removing all rows or columns containing one or more `NaN`s, removing rows or columns based on the occurrence of `NaN`s within specific rows or columns, or filling in `NaN` values with another value.
#
# We want to work with paintings that have artist information associated with them. A painting that does not have artist information can be identified by a value of `NaN` in the column `ArtistBio`. We will create a subset of the full `paintings` DataFrame by removing all rows that contain `NaN` in the `ArtistBio` column using the DataFrame method `dropna()` and specifying a column `subset` over which to look for `NaN`s.

# %%
# Create a new DataFrame containing only paintings that include artist
# information by removing rows that include "NaN" in the column "ArtistBio"
# using the DataFrame method dropna()
paintings_clean = paintings.dropna(subset=['ArtistBio'])

# Print out the resulting DataFrame
paintings_clean
# Out:
#                             Title          Artist  ConstituentID  \
# 1              Rope and People, I       Joan Miró         4016.0
# 2             Fire in the Evening       Paul Klee         3130.0
# 3      Portrait of an Equilibrist       Paul Klee         3130.0
# 4                          Guitar   Pablo Picasso         4609.0
# 5                     Grandmother     Arthur Dove         1602.0
# ...                           ...             ...            ...
# 38098                Zacimba Gaba    Dalton Paula       132719.0
# 38099                       Zumbi    Dalton Paula       132719.0
# 38100                  Vertigo #2  Ouattara Watts       132954.0
# 38101        Lot 111113 (flare 1)  Donald Moffett         7435.0
# 38102           Unknown Pleasures    Matthew Wong       132956.0
#
#                             Date  \
# 1      Barcelona, March 27, 1935
# 2                           1929
# 3                           1927
# 4              Paris, early 1919
# 5                           1925
# ...                          ...
# 38098                       2020
# 38099                       2020
# 38100                       2011
# 38101                       2013
# 38102                       2019
#
#                                                   Medium  \
# 1      Oil on cardboard mounted on wood, with coil of...
# 2                                       Oil on cardboard
# 3      Oil and collage on cardboard over wood with pa...
# 4               Oil, charcoal and pinned paper on canvas
# 5      Shingles, needlepoint, page from Concordance, ...
# ...                                                  ...
# 38098  Oil, pencil, and gold leaf on two joined canvases
# 38099  Oil, pencil, and gold leaf on two joined canvases
# 38100  Acrylic, paper pulp, cut and pasted fabrics, a...
# 38101  Acrylic and lacquer on linen with cotton and a...
# 38102                                      Oil on canvas
#
#                                               Dimensions  \
# 1                     41 1/4 x 29 3/8" (104.8 x 74.6 cm)
# 2                      13 3/8 x 13 1/4" (33.8 x 33.3 cm)
# 3                        24 7/8 x 15 3/4" (63.2 x 40 cm)
# 4                            7' 1" x 31" (216 x 78.8 cm)
# 5                          20 x 21 1/4" (50.8 x 54.0 cm)
# ...                                                  ...
# 38098          24 × 17 3/4" (61 × 45.1 cm), in two parts
# 38099          24 × 17 3/4" (61 × 45.1 cm), in two parts
# 38100  118 1/4 × 165 1/2 × 3 3/4" (300.4 × 420.4 × 9....
# 38101                        54 × 44" (137.2 × 111.8 cm)
# 38102                        65 × 65" (165.1 × 165.1 cm)
#
#                                     CreditLine AccessionNumber Classification  \
# 1           Gift of the Pierre Matisse Gallery         71.1936       Painting
# 2      Mr. and Mrs. Joachim Jean Aberbach Fund        153.1970       Painting
# 3                   Mrs. Simon Guggenheim Fund        195.1966       Painting
# 4                   Gift of A. Conger Goodyear        384.1955       Painting
# 5      Gift of Philip L. Goodwin (by exchange)        636.1939       Painting
# ...                                        ...             ...            ...
# 38098                                      NaN       TR16514.1       Painting
# 38099                                      NaN       TR16514.2       Painting
# 38100                                      NaN         TR16516       Painting
# 38101                                      NaN         TR16517       Painting
# 38102                                      NaN         TR16518       Painting
#
#                  Department  ... Weight (kg)  Width (cm)  Duration (sec.)  \
# 1      Painting & Sculpture  ...         NaN   74.600000              NaN
# 2      Painting & Sculpture  ...         NaN   33.300000              NaN
# 3      Painting & Sculpture  ...         NaN   36.800000              NaN
# 4      Painting & Sculpture  ...         NaN   78.700000              NaN
# 5      Painting & Sculpture  ...         NaN   54.000000              NaN
# ...                     ...  ...         ...         ...              ...
# 38098  Painting & Sculpture  ...         NaN   45.085090              NaN
# 38099  Painting & Sculpture  ...         NaN   45.085090              NaN
# 38100  Painting & Sculpture  ...         NaN  420.370841              NaN
# 38101  Painting & Sculpture  ...         NaN  111.760224              NaN
# 38102  Painting & Sculpture  ...         NaN  165.100330              NaN
#
#                                  ArtistBio  Nationality  Gender  BeginDate  \
# 1                       Spanish, 1893–1983      Spanish    Male     1893.0
# 2      German, born Switzerland. 1879–1940       German    Male     1879.0
# 3      German, born Switzerland. 1879–1940       German    Male     1879.0
# 4                       Spanish, 1881–1973      Spanish    Male     1881.0
# 5                      American, 1880–1946     American    Male     1880.0
# ...                                    ...          ...     ...        ...
# 38098                 Brazilian, born 1982    Brazilian     NaN     1982.0
# 38099                 Brazilian, born 1982    Brazilian     NaN     1982.0
# 38100     American, born Ivory Coast, 1957     American     NaN     1957.0
# 38101                  American, born 1955     American    Male     1955.0
# 38102                Canadian, 1984 - 2019          NaN     NaN        0.0
#
#        EndDate    Area (cm^2)  OilPainting
# 1       1983.0    7818.080000          Yes
# 2       1940.0    1125.540000          Yes
# 3       1940.0    2219.040000          Yes
# 4       1973.0   16991.330000          Yes
# 5       1946.0    2743.200000           No
# ...        ...            ...          ...
# 38098      0.0    2748.392594          Yes
# 38099      0.0    2748.392594          Yes
# 38100      0.0  126260.736392           No
# 38101      0.0   15329.062916           No
# 38102      0.0   27258.119032          Yes
#
# [2348 rows x 28 columns]

# %% [markdown]
# ### Working with string data
#
# A lot of the MoMA data consists of strings. There is currently no string data type in pandas, strings are represented by the pandas *object* data type. We can apply string methods to pandas arrays by accessing the `.str` attribute of the array. For example, we can access the string values of the `Artists` column in the full dataset by calling `moma_data[Artists].str`.
#
# If we look at the `Gender` column, we see that the gender types are not represented in a normalized way (for example, female is represented in some cases by the value `Female` and in other cases `female`). We will use the `lower()` string method to produce a lowercase string for all values in the `Gender` column.

# %%
# Print the unique values contained in the "Gender" column using the
# DataFrame method unique()
paintings_clean['Gender'].unique()
# Out:
# array(['Male', 'Female', 'male', nan, 'female'], dtype=object)

# %%
# Reassign the column "Gender" with the results of calling the string method
# lower() on the values in the "Gender" column
paintings_clean['Gender'] = paintings_clean['Gender'].str.lower()

# Print the unique values contained in the "Gender" column using the
# DataFrame method unique()
paintings_clean['Gender'].unique()
# Out:
# <ipython-input-11-3f475057bfb4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   paintings_clean['Gender'] = paintings_clean['Gender'].str.lower()
# array(['male', 'female', nan], dtype=object)

# %% [markdown]
# ### Working with Datetime data
#
# Our MoMA dataset contains some columns of data that represent date values (for example, `DateAcquired`, `BeginDate`, `EndDate`). Currently, each of these columns is recognized as strings (the pandas object datatype). If we look at the `DateAcquired` column we see that it contains the date that an artwork was acquired by the museum in the form `YYYY-MM-DD` (for example, `1964-10-06`). If we wanted to filter these values by year, we would not be able to do this in their current string format.
#
# We can convert the values in the `DateAcquired` column to a pandas Datetime data type to use them as a datetime format, a format for a value that contains date and time information, using the pandas method `to_datetime()` on the column.

# %%
# Reassign the string values in the column "DateAcquired" as Datetime values
# using the pandas method to_datetime()
paintings_clean['DateAcquired'] = pd.to_datetime(
    paintings_clean['DateAcquired']
)

# Print out the new "DateAcquired" column
paintings_clean['DateAcquired']
# Out:
# <ipython-input-12-d645fe276cd8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   paintings_clean['DateAcquired'] = pd.to_datetime(paintings_clean['DateAcquired'])
# 1       1936-10-16
# 2       1970-04-08
# 3       1966-04-12
# 4       1955-12-28
# 5       1939-12-08
#            ...
# 38098   2020-10-26
# 38099   2020-10-26
# 38100   2020-10-26
# 38101   2020-10-26
# 38102   2020-10-26
# Name: DateAcquired, Length: 2348, dtype: datetime64[ns]

# %% [markdown]
# We can now filter the DataFrame by date, based on the values in the `DataAcquired` column. Let's filter the cleaned paintings DataFrame to only include paintings acquired before 1960

# %%
# Filter the cleaned paintings DataFrame to only include paintings acquired
# before 1960
paintings_clean[paintings_clean['DateAcquired'] < pd.to_datetime('1960')]
# Out:
#                                Title                  Artist  ConstituentID  \
# 1                 Rope and People, I               Joan Miró         4016.0
# 4                             Guitar           Pablo Picasso         4609.0
# 5                        Grandmother             Arthur Dove         1602.0
# 19213          Daylight Savings Time              Pierre Roy         5065.0
# 19214                     The Bather            Paul Cézanne         1053.0
# ...                              ...                     ...            ...
# 20955  Tribulations of Saint Anthony             James Ensor         1739.0
# 20956              Leaves and Navels         Jean (Hans) Arp           11.0
# 20957                    Ethnography  David Alfaro Siqueiros         5454.0
# 21063                  Colorhythm, 1         Alejandro Otero         4445.0
# 23220                   Château Noir            Paul Cézanne         1053.0
#
#                             Date  \
# 1      Barcelona, March 27, 1935
# 4              Paris, early 1919
# 5                           1925
# 19213                       1929
# 19214                    c. 1885
# ...                          ...
# 20955                       1887
# 20956                       1929
# 20957                       1939
# 21063                       1955
# 23220                    1903-04
#
#                                                   Medium  \
# 1      Oil on cardboard mounted on wood, with coil of...
# 4               Oil, charcoal and pinned paper on canvas
# 5      Shingles, needlepoint, page from Concordance, ...
# 19213                                      Oil on canvas
# 19214                                      Oil on canvas
# ...                                                  ...
# 20955                                      Oil on canvas
# 20956                             Oil and cord on canvas
# 20957                                    Enamel on board
# 21063                                  Enamel on plywood
# 23220                                      Oil on canvas
#
#                                Dimensions  \
# 1      41 1/4 x 29 3/8" (104.8 x 74.6 cm)
# 4             7' 1" x 31" (216 x 78.8 cm)
# 5           20 x 21 1/4" (50.8 x 54.0 cm)
# 19213       21 1/2 x 15" (54.6 x 38.1 cm)
# 19214        50 x 38 1/8" (127 x 96.8 cm)
# ...                                   ...
# 20955     46 3/8 x 66" (117.8 x 167.6 cm)
# 20956     13 3/4 x 10 3/4" (35 x 27.3 cm)
# 20957  48 1/8 x 32 3/8" (122.2 x 82.2 cm)
# 21063   6' 6 3/4" x 19" (200.1 x 48.2 cm)
# 23220       29 x 36 3/4" (73.6 x 93.2 cm)
#
#                                               CreditLine AccessionNumber  \
# 1                     Gift of the Pierre Matisse Gallery         71.1936
# 4                             Gift of A. Conger Goodyear        384.1955
# 5                Gift of Philip L. Goodwin (by exchange)        636.1939
# 19213                     Gift of Mrs. Ray Slater Murphy          1.1931
# 19214  Lillie P. Bliss Collection. Conservation was m...          1.1934
# ...                                                  ...             ...
# 20955                                           Purchase       1642.1940
# 20956                                           Purchase       1647.1940
# 20957                   Gift of Abby Aldrich Rockefeller       1657.1940
# 21063                                Inter-American Fund         21.1956
# 23220                         Gift of Mrs. David M. Levy        137.1957
#
#       Classification            Department  ... Weight (kg) Width (cm)  \
# 1           Painting  Painting & Sculpture  ...         NaN    74.6000
# 4           Painting  Painting & Sculpture  ...         NaN    78.7000
# 5           Painting  Painting & Sculpture  ...         NaN    54.0000
# 19213       Painting  Painting & Sculpture  ...         NaN    38.1000
# 19214       Painting  Painting & Sculpture  ...         NaN    96.8000
# ...              ...                   ...  ...         ...        ...
# 20955       Painting  Painting & Sculpture  ...         NaN   167.6000
# 20956       Painting  Painting & Sculpture  ...         NaN    27.3000
# 20957       Painting  Painting & Sculpture  ...         NaN    82.2000
# 21063       Painting  Painting & Sculpture  ...         NaN    48.2000
# 23220       Painting  Painting & Sculpture  ...         NaN    93.3452
#
#        Duration (sec.)                                 ArtistBio  Nationality  \
# 1                  NaN                        Spanish, 1893–1983      Spanish
# 4                  NaN                        Spanish, 1881–1973      Spanish
# 5                  NaN                       American, 1880–1946     American
# 19213              NaN                         French, 1880–1950       French
# 19214              NaN                         French, 1839–1906       French
# ...                ...                                       ...          ...
# 20955              NaN                        Belgian, 1860–1949      Belgian
# 20956              NaN  French, born Germany (Alsace). 1886–1966       French
# 20957              NaN                        Mexican, 1896–1974      Mexican
# 21063              NaN                     Venezuelan, 1921–1990   Venezuelan
# 23220              NaN                         French, 1839–1906       French
#
#        Gender  BeginDate  EndDate  Area (cm^2)  OilPainting
# 1        male     1893.0   1983.0   7818.08000          Yes
# 4        male     1881.0   1973.0  16991.33000          Yes
# 5        male     1880.0   1946.0   2743.20000           No
# 19213    male     1880.0   1950.0   2080.26000          Yes
# 19214    male     1839.0   1906.0  12293.60000          Yes
# ...       ...        ...      ...          ...          ...
# 20955    male     1860.0   1949.0  19743.28000          Yes
# 20956    male     1886.0   1966.0    955.50000          Yes
# 20957    male     1896.0   1974.0  10044.84000           No
# 21063    male     1921.0   1990.0   9644.82000           No
# 23220    male     1839.0   1906.0   6870.20672          Yes
#
# [635 rows x 28 columns]

# %% [markdown]
# ----
#
# ## Open work time
#
# You can use this time to ask questions, collaborate, or work on the following exercises (on your own or in a group).
#
# For these exercises you will be using a dataset that consists of MoMA artworks classified as photographs and each photograph's associated artist information. This dataset has the same columns and column names as the original paintings dataset from the guided activity.
#
# Before starting the exercises you will need to load the new dataset as DataFrames. It is available as a CSV file and the URL to the file is provided in the variable below.

# %%
# URLs to the photographs dataset
photos_file_url = 'https://raw.githubusercontent.com/ncsu-libraries-data-vis/teaching-datasets/main/moma_data/moma_photographs_full.csv'

# Import the photographs dataset as a DataFrame
photos = pd.read_csv(photos_file_url)
photos
# Out:
#                                         Title                Artist  \
# 0                 Untitled from VVV Portfolio            David Hare
# 7      Tuileries Sanglier / d'apres l'antique          Eugène Atget
# 8                             Sapin (Trianon)          Eugène Atget
# 9                 Versailles, vase par Ballin          Eugène Atget
# 10                                    Facteur          Eugène Atget
# ...                                       ...                   ...
# 38133                                Untitled  Unknown photographer
# 38134                                Untitled  Unknown photographer
# 38135                                Untitled  Unknown photographer
# 38136                                Untitled  Unknown photographer
# 38137                      Silver Springs, FL  Unknown photographer
#
#        ConstituentID                     Date  \
# 0             2504.0  c. 1941, published 1943
# 7              229.0                     1911
# 8              229.0                  1910-14
# 9              229.0                     1902
# 10             229.0                1899-1900
# ...              ...                      ...
# 38133         8595.0                  c. 1910
# 38134         8595.0                  c. 1910
# 38135         8595.0               c. 1918-30
# 38136         8595.0                  c. 1900
# 38137         8595.0            February 1903
#
#                                                   Medium  \
# 0      Gelatin silver print mounted on paper from a p...
# 7                                   Albumen silver print
# 8                                   Albumen silver print
# 9                             Matte albumen silver print
# 10               Gelatin silver printing-out-paper print
# ...                                                  ...
# 38133                               Gelatin silver print
# 38134                Gelatin silver print, printed later
# 38135                    Gelatin silver print (postcard)
# 38136                               Gelatin silver print
# 38137                               Gelatin silver print
#
#                                               Dimensions  \
# 0      composition: 12 x 9 3/4" (30.5 x 24.8 cm); she...
# 7                       8 11/16 × 6 9/16" (22 × 16.7 cm)
# 8                Approx. 7 1/8 × 8 5/8" (18.1 × 21.9 cm)
# 9                Approx. 8 9/16 × 7 1/16" (21.8 × 18 cm)
# 10              Approx. 8 11/16 × 6 9/16" (22 × 16.7 cm)
# ...                                                  ...
# 38133                       2 3/8 × 4 1/8" (6 × 10.5 cm)
# 38134                 8 1/16 × 13 1/16" (20.5 × 33.2 cm)
# 38135                         4 × 3 3/8" (10.2 × 8.6 cm)
# 38136                   6 7/16 × 9 3/4" (16.4 × 24.7 cm)
# 38137                   3 7/16 × 11 13/16" (8.8 × 30 cm)
#
#                                               CreditLine AccessionNumber  \
# 0                          The Louis E. Stern Collection     1113.1964.6
# 7      Abbott-Levy Collection. Partial gift of Shirle...        1.1969.1
# 8      Abbott-Levy Collection. Partial gift of Shirle...       1.1969.10
# 9      Abbott-Levy Collection. Partial gift of Shirle...      1.1969.100
# 10     Abbott-Levy Collection. Partial gift of Shirle...     1.1969.1000
# ...                                                  ...             ...
# 38133                     Gift of John Jeremiah Sullivan      TR16527.20
# 38134                     Gift of John Jeremiah Sullivan      TR16527.21
# 38135                     Gift of John Jeremiah Sullivan      TR16527.22
# 38136                     Gift of John Jeremiah Sullivan      TR16527.23
# 38137                     Gift of John Jeremiah Sullivan      TR16527.24
#
#       Classification         Department  ... Height (cm) Length (cm)  \
# 0         Photograph  Drawings & Prints  ...       30.50         NaN
# 7         Photograph        Photography  ...         NaN         NaN
# 8         Photograph        Photography  ...         NaN         NaN
# 9         Photograph        Photography  ...         NaN         NaN
# 10        Photograph        Photography  ...         NaN         NaN
# ...              ...                ...  ...         ...         ...
# 38133     Photograph        Photography  ...        6.00         NaN
# 38134     Photograph        Photography  ...       20.50         NaN
# 38135     Photograph        Photography  ...       10.20         NaN
# 38136     Photograph        Photography  ...       16.36         NaN
# 38137     Photograph        Photography  ...        8.80         NaN
#
#        Weight (kg)  Width (cm)  Duration (sec.)            ArtistBio  \
# 0              NaN        24.8              NaN  American, 1917–1992
# 7              NaN         NaN              NaN    French, 1857–1927
# 8              NaN         NaN              NaN    French, 1857–1927
# 9              NaN         NaN              NaN    French, 1857–1927
# 10             NaN         NaN              NaN    French, 1857–1927
# ...            ...         ...              ...                  ...
# 38133          NaN        10.5              NaN                  NaN
# 38134          NaN        33.2              NaN                  NaN
# 38135          NaN         8.6              NaN                  NaN
# 38136          NaN        24.7              NaN                  NaN
# 38137          NaN        30.0              NaN                  NaN
#
#        Nationality  Gender  BeginDate  EndDate
# 0         American    Male     1917.0   1992.0
# 7           French    Male     1857.0   1927.0
# 8           French    Male     1857.0   1927.0
# 9           French    Male     1857.0   1927.0
# 10          French    Male     1857.0   1927.0
# ...            ...     ...        ...      ...
# 38133          NaN     NaN        0.0      0.0
# 38134          NaN     NaN        0.0      0.0
# 38135          NaN     NaN        0.0      0.0
# 38136          NaN     NaN        0.0      0.0
# 38137          NaN     NaN        0.0      0.0
#
# [31443 rows x 26 columns]

# %% [markdown]
# ### Exercise 1: Rename column values
#
# In the photographs dataset, replace the values in the column `Cataloged`. Replace all occurrences of the value `Y` with the value `Yes` and all occurrences of the value `N` with the value `No`. Overwrite the existing values with the new values.

# %%
# Replace the values "Y" and "N" in the "Cataloged" column with "Yes" and "No"
photos['Cataloged'].replace({'Y': 'Yes', 'N': 'No'}, inplace=True)
# Out:
# 0        Yes
# 7        Yes
# 8        Yes
# 9        Yes
# 10       Yes
#         ...
# 38133    Yes
# 38134    Yes
# 38135    Yes
# 38136    Yes
# 38137    Yes
# Name: Cataloged, Length: 31443, dtype: object

# %% [markdown]
# ### Exercise 2: Create a new column using an expression
#
# Create a new column, `Aspect`, that contains the aspect ratio (width / height) of a photograph using the values in the `Width (cm)` and `Height (cm)` columns.

# %%
# Create a new column named "Aspect" that contains the aspect ratio of a
# photograph based on the values in columns "Width (cm)" and "Height (cm)"
photos['Aspect'] = photos['Width (cm)'] / photos['Height (cm)']
photos
# Out:
#                                         Title                Artist  \
# 0                 Untitled from VVV Portfolio            David Hare
# 7      Tuileries Sanglier / d'apres l'antique          Eugène Atget
# 8                             Sapin (Trianon)          Eugène Atget
# 9                 Versailles, vase par Ballin          Eugène Atget
# 10                                    Facteur          Eugène Atget
# ...                                       ...                   ...
# 38133                                Untitled  Unknown photographer
# 38134                                Untitled  Unknown photographer
# 38135                                Untitled  Unknown photographer
# 38136                                Untitled  Unknown photographer
# 38137                      Silver Springs, FL  Unknown photographer
#
#        ConstituentID                     Date  \
# 0             2504.0  c. 1941, published 1943
# 7              229.0                     1911
# 8              229.0                  1910-14
# 9              229.0                     1902
# 10             229.0                1899-1900
# ...              ...                      ...
# 38133         8595.0                  c. 1910
# 38134         8595.0                  c. 1910
# 38135         8595.0               c. 1918-30
# 38136         8595.0                  c. 1900
# 38137         8595.0            February 1903
#
#                                                   Medium  \
# 0      Gelatin silver print mounted on paper from a p...
# 7                                   Albumen silver print
# 8                                   Albumen silver print
# 9                             Matte albumen silver print
# 10               Gelatin silver printing-out-paper print
# ...                                                  ...
# 38133                               Gelatin silver print
# 38134                Gelatin silver print, printed later
# 38135                    Gelatin silver print (postcard)
# 38136                               Gelatin silver print
# 38137                               Gelatin silver print
#
#                                               Dimensions  \
# 0      composition: 12 x 9 3/4" (30.5 x 24.8 cm); she...
# 7                       8 11/16 × 6 9/16" (22 × 16.7 cm)
# 8                Approx. 7 1/8 × 8 5/8" (18.1 × 21.9 cm)
# 9                Approx. 8 9/16 × 7 1/16" (21.8 × 18 cm)
# 10              Approx. 8 11/16 × 6 9/16" (22 × 16.7 cm)
# ...                                                  ...
# 38133                       2 3/8 × 4 1/8" (6 × 10.5 cm)
# 38134                 8 1/16 × 13 1/16" (20.5 × 33.2 cm)
# 38135                         4 × 3 3/8" (10.2 × 8.6 cm)
# 38136                   6 7/16 × 9 3/4" (16.4 × 24.7 cm)
# 38137                   3 7/16 × 11 13/16" (8.8 × 30 cm)
#
#                                               CreditLine AccessionNumber  \
# 0                          The Louis E. Stern Collection     1113.1964.6
# 7      Abbott-Levy Collection. Partial gift of Shirle...        1.1969.1
# 8      Abbott-Levy Collection. Partial gift of Shirle...       1.1969.10
# 9      Abbott-Levy Collection. Partial gift of Shirle...      1.1969.100
# 10     Abbott-Levy Collection. Partial gift of Shirle...     1.1969.1000
# ...                                                  ...             ...
# 38133                     Gift of John Jeremiah Sullivan      TR16527.20
# 38134                     Gift of John Jeremiah Sullivan      TR16527.21
# 38135                     Gift of John Jeremiah Sullivan      TR16527.22
# 38136                     Gift of John Jeremiah Sullivan      TR16527.23
# 38137                     Gift of John Jeremiah Sullivan      TR16527.24
#
#       Classification         Department  ... Length (cm) Weight (kg)  \
# 0         Photograph  Drawings & Prints  ...         NaN         NaN
# 7         Photograph        Photography  ...         NaN         NaN
# 8         Photograph        Photography  ...         NaN         NaN
# 9         Photograph        Photography  ...         NaN         NaN
# 10        Photograph        Photography  ...         NaN         NaN
# ...              ...                ...  ...         ...         ...
# 38133     Photograph        Photography  ...         NaN         NaN
# 38134     Photograph        Photography  ...         NaN         NaN
# 38135     Photograph        Photography  ...         NaN         NaN
# 38136     Photograph        Photography  ...         NaN         NaN
# 38137     Photograph        Photography  ...         NaN         NaN
#
#        Width (cm)  Duration (sec.)            ArtistBio  Nationality  Gender  \
# 0            24.8              NaN  American, 1917–1992     American    Male
# 7             NaN              NaN    French, 1857–1927       French    Male
# 8             NaN              NaN    French, 1857–1927       French    Male
# 9             NaN              NaN    French, 1857–1927       French    Male
# 10            NaN              NaN    French, 1857–1927       French    Male
# ...           ...              ...                  ...          ...     ...
# 38133        10.5              NaN                  NaN          NaN     NaN
# 38134        33.2              NaN                  NaN          NaN     NaN
# 38135         8.6              NaN                  NaN          NaN     NaN
# 38136        24.7              NaN                  NaN          NaN     NaN
# 38137        30.0              NaN                  NaN          NaN     NaN
#
#        BeginDate  EndDate    Aspect
# 0         1917.0   1992.0  0.813115
# 7         1857.0   1927.0       NaN
# 8         1857.0   1927.0       NaN
# 9         1857.0   1927.0       NaN
# 10        1857.0   1927.0       NaN
# ...          ...      ...       ...
# 38133        0.0      0.0  1.750000
# 38134        0.0      0.0  1.619512
# 38135        0.0      0.0  0.843137
# 38136        0.0      0.0  1.509780
# 38137        0.0      0.0  3.409091
#
# [31443 rows x 27 columns]

# %% [markdown]
# ### Exercise 3: Create a new column using apply
#
# Use the values in the column `BeginDate` to create a new column, `CenturyBorn`, in the photos DataFrame that indicates the century in which an artist was born using a function that returns:
# - `18th` if the artist was born between 1700-1799,
# - `19th` if the artist was born between 1800-1899,
# - `20th` if the artist was born between 1900-1999,
# - `21st` if the artist was born between 2000-present, and
# - `unknown` otherwise.
#
# The `BeginDate` column contains the year in which an artist was born. Unknown artist birth years are identified with the value `0`. The function `century_born()` has been provided for you to use with the apply method, but you can create your own for extra practice.

# %%
# Return the century in which an artist was born given their birth year
def century_born(year):
    if year > 1999:
        return '21st'
    elif year > 1899:
        return '20th'
    elif year > 1799:
        return '19th'
    elif year > 1699:
        return '18th'
    return 'unknown'

# Create a new column named "CenturyBorn" that contains the century in which an
# artist was born using data from the column "BeginDate" and the function
# century_born
photos['CenturyBorn'] = photos['BeginDate'].apply(century_born)

photos[['CenturyBorn', 'BeginDate']]
# Out:
#       CenturyBorn  BeginDate
# 0            20th     1917.0
# 7            19th     1857.0
# 8            19th     1857.0
# 9            19th     1857.0
# 10           19th     1857.0
# ...           ...        ...
# 38133     unknown        0.0
# 38134     unknown        0.0
# 38135     unknown        0.0
# 38136     unknown        0.0
# 38137     unknown        0.0
#
# [31443 rows x 2 columns]

# %% [markdown]
# ### Exercise 4: Remove missing values
#
# We are only interested in artworks that have a defined width and height. Use the column `Aspect` to remove any rows from the dataset that do not have a defined aspect ratio (in other words, values that are `NaN`).

# %%
# Remove rows from the dataset that have an "NaN" value in the "Aspect" column
photos_clean = photos.dropna(subset=['Aspect'])

photos_clean
# Out:
#                              Title                Artist  ConstituentID  \
# 0      Untitled from VVV Portfolio            David Hare         2504.0
# 13             Marchand de paniers          Eugène Atget          229.0
# 15              Porte de Montreuil          Eugène Atget          229.0
# 272               Versailles, vase          Eugène Atget          229.0
# 277              Bords de la Marne          Eugène Atget          229.0
# ...                            ...                   ...            ...
# 38133                     Untitled  Unknown photographer         8595.0
# 38134                     Untitled  Unknown photographer         8595.0
# 38135                     Untitled  Unknown photographer         8595.0
# 38136                     Untitled  Unknown photographer         8595.0
# 38137           Silver Springs, FL  Unknown photographer         8595.0
#
#                           Date  \
# 0      c. 1941, published 1943
# 13                   1899-1900
# 15                        1913
# 272                       1905
# 277                       1903
# ...                        ...
# 38133                  c. 1910
# 38134                  c. 1910
# 38135               c. 1918-30
# 38136                  c. 1900
# 38137            February 1903
#
#                                                   Medium  \
# 0      Gelatin silver print mounted on paper from a p...
# 13                                  Albumen silver print
# 15                            Matte albumen silver print
# 272                                 Albumen silver print
# 277              Gelatin silver printing-out-paper print
# ...                                                  ...
# 38133                               Gelatin silver print
# 38134                Gelatin silver print, printed later
# 38135                    Gelatin silver print (postcard)
# 38136                               Gelatin silver print
# 38137                               Gelatin silver print
#
#                                               Dimensions  \
# 0      composition: 12 x 9 3/4" (30.5 x 24.8 cm); she...
# 13                       8 3/8 × 6 5/8" (21.3 × 16.8 cm)
# 15                           9 × 6 7/8" (22.8 × 17.5 cm)
# 272                  Approx. 8 7/8 × 7" (22.5 × 17.8 cm)
# 277                      6 11/16 × 8 3/4" (17 × 22.2 cm)
# ...                                                  ...
# 38133                       2 3/8 × 4 1/8" (6 × 10.5 cm)
# 38134                 8 1/16 × 13 1/16" (20.5 × 33.2 cm)
# 38135                         4 × 3 3/8" (10.2 × 8.6 cm)
# 38136                   6 7/16 × 9 3/4" (16.4 × 24.7 cm)
# 38137                   3 7/16 × 11 13/16" (8.8 × 30 cm)
#
#                                               CreditLine AccessionNumber  \
# 0                          The Louis E. Stern Collection     1113.1964.6
# 13     Abbott-Levy Collection. Partial gift of Shirle...     1.1969.1003
# 15     Abbott-Levy Collection. Partial gift of Shirle...     1.1969.1005
# 272    Abbott-Levy Collection. Partial gift of Shirle...      1.1969.124
# 277    Abbott-Levy Collection. Partial gift of Shirle...     1.1969.1244
# ...                                                  ...             ...
# 38133                     Gift of John Jeremiah Sullivan      TR16527.20
# 38134                     Gift of John Jeremiah Sullivan      TR16527.21
# 38135                     Gift of John Jeremiah Sullivan      TR16527.22
# 38136                     Gift of John Jeremiah Sullivan      TR16527.23
# 38137                     Gift of John Jeremiah Sullivan      TR16527.24
#
#       Classification         Department  ... Weight (kg) Width (cm)  \
# 0         Photograph  Drawings & Prints  ...         NaN       24.8
# 13        Photograph        Photography  ...         NaN       16.8
# 15        Photograph        Photography  ...         NaN       17.5
# 272       Photograph        Photography  ...         NaN       17.8
# 277       Photograph        Photography  ...         NaN       22.2
# ...              ...                ...  ...         ...        ...
# 38133     Photograph        Photography  ...         NaN       10.5
# 38134     Photograph        Photography  ...         NaN       33.2
# 38135     Photograph        Photography  ...         NaN        8.6
# 38136     Photograph        Photography  ...         NaN       24.7
# 38137     Photograph        Photography  ...         NaN       30.0
#
#        Duration (sec.)            ArtistBio  Nationality  Gender  BeginDate  \
# 0                  NaN  American, 1917–1992     American    Male     1917.0
# 13                 NaN    French, 1857–1927       French    Male     1857.0
# 15                 NaN    French, 1857–1927       French    Male     1857.0
# 272                NaN    French, 1857–1927       French    Male     1857.0
# 277                NaN    French, 1857–1927       French    Male     1857.0
# ...                ...                  ...          ...     ...        ...
# 38133              NaN                  NaN          NaN     NaN        0.0
# 38134              NaN                  NaN          NaN     NaN        0.0
# 38135              NaN                  NaN          NaN     NaN        0.0
# 38136              NaN                  NaN          NaN     NaN        0.0
# 38137              NaN                  NaN          NaN     NaN        0.0
#
#        EndDate    Aspect  CenturyBorn
# 0       1992.0  0.813115         20th
# 13      1927.0  0.788732         19th
# 15      1927.0  0.767544         19th
# 272     1927.0  0.791111         19th
# 277     1927.0  1.305882         19th
# ...        ...       ...          ...
# 38133      0.0  1.750000      unknown
# 38134      0.0  1.619512      unknown
# 38135      0.0  0.843137      unknown
# 38136      0.0  1.509780      unknown
# 38137      0.0  3.409091      unknown
#
# [24936 rows x 28 columns]

# %% [markdown]
# ### Exercise 5: Use a string method to normalize data
#
# Normalize the values in the column `Gender` by applying the string method `title()` to convert all strings to title case (for example, convert `male` to `Male` and `female` to `Female`). Print out the unique values of this column after performing the operation to ensure only three values are present (`Male`, `Female`, and `nan`).

# %%
# Normalize the string values in the "Gender" column to title case (each word
# beginning with a capital letter)
photos['Gender'].str.title().unique()
# Out:
# array(['Male', 'Female', nan, 'male'], dtype=object)

# %% [markdown]
# ### Exercise 6: Convert string data to Datetime
#
# Convert the string data contained in the column `DateAcquired` to Datetime data type. Reassign the new Datetime values to the existing `DateAcquired` column and then use this column to filter the DataFrame for items acquired in or after the year 2020.

# %%
# Convert the string data in the column "DateAcquired" to a Datetime data type
photos['DateAcquired'] = pd.to_datetime(photos['DateAcquired'])

# Use the updated column to filter the DataFrame to photos acquired in or after
# the year 2020
photos[photos['DateAcquired'] >= pd.to_datetime('2020')]
# Out:
#                     Title                Artist  ConstituentID           Date  \
# 37502            Untitled       Alfredo Boulton        20354.0           1934
# 37510            Untitled      Victoria Cabezas       132160.0        1983-84
# 37512            Untitled       Alfredo Boulton        20354.0           1934
# 37513            Untitled       Alfredo Boulton        20354.0           1934
# 37514            Untitled       Alfredo Boulton        20354.0           1934
# ...                   ...                   ...            ...            ...
# 38133            Untitled  Unknown photographer         8595.0        c. 1910
# 38134            Untitled  Unknown photographer         8595.0        c. 1910
# 38135            Untitled  Unknown photographer         8595.0     c. 1918-30
# 38136            Untitled  Unknown photographer         8595.0        c. 1900
# 38137  Silver Springs, FL  Unknown photographer         8595.0  February 1903
#
#                                     Medium  \
# 37502                 Gelatin silver print
# 37510  Chromogenic color print (solarized)
# 37512                 Gelatin silver print
# 37513                 Gelatin silver print
# 37514                 Gelatin silver print
# ...                                    ...
# 38133                 Gelatin silver print
# 38134  Gelatin silver print, printed later
# 38135      Gelatin silver print (postcard)
# 38136                 Gelatin silver print
# 38137                 Gelatin silver print
#
#                                Dimensions  \
# 37502      9 1/2 × 7 1/16" (24.2 × 18 cm)
# 37510        10 × 8 7/8" (25.4 × 22.5 cm)
# 37512      9 5/8 × 7 1/16" (24.5 × 18 cm)
# 37513      6 7/8 × 9 7/16" (17.4 × 24 cm)
# 37514     9 3/4 × 6 3/4" (24.8 × 17.1 cm)
# ...                                   ...
# 38133        2 3/8 × 4 1/8" (6 × 10.5 cm)
# 38134  8 1/16 × 13 1/16" (20.5 × 33.2 cm)
# 38135          4 × 3 3/8" (10.2 × 8.6 cm)
# 38136    6 7/16 × 9 3/4" (16.4 × 24.7 cm)
# 38137    3 7/16 × 11 13/16" (8.8 × 30 cm)
#
#                                               CreditLine AccessionNumber  \
# 37502  Gift of Sofía Maduro through the Latin America...       28.2020.1
# 37510  Acquired through the generosity of Judko Rosen...       TR16426.1
# 37512  Gift of Sofía Maduro through the Latin America...       28.2020.2
# 37513  Gift of Sofía Maduro through the Latin America...       28.2020.3
# 37514  Gift of Sofía Maduro through the Latin America...       28.2020.4
# ...                                                  ...             ...
# 38133                     Gift of John Jeremiah Sullivan      TR16527.20
# 38134                     Gift of John Jeremiah Sullivan      TR16527.21
# 38135                     Gift of John Jeremiah Sullivan      TR16527.22
# 38136                     Gift of John Jeremiah Sullivan      TR16527.23
# 38137                     Gift of John Jeremiah Sullivan      TR16527.24
#
#       Classification   Department  ... Weight (kg) Width (cm)  \
# 37502     Photograph  Photography  ...         NaN       18.0
# 37510     Photograph  Photography  ...         NaN       22.5
# 37512     Photograph  Photography  ...         NaN       18.0
# 37513     Photograph  Photography  ...         NaN       24.0
# 37514     Photograph  Photography  ...         NaN       17.1
# ...              ...          ...  ...         ...        ...
# 38133     Photograph  Photography  ...         NaN       10.5
# 38134     Photograph  Photography  ...         NaN       33.2
# 38135     Photograph  Photography  ...         NaN        8.6
# 38136     Photograph  Photography  ...         NaN       24.7
# 38137     Photograph  Photography  ...         NaN       30.0
#
#        Duration (sec.)              ArtistBio  Nationality  Gender  BeginDate  \
# 37502              NaN  Venezuelan, 1908–1995   Venezuelan    Male     1908.0
# 37510              NaN    American, born 1950     American  Female     1950.0
# 37512              NaN  Venezuelan, 1908–1995   Venezuelan    Male     1908.0
# 37513              NaN  Venezuelan, 1908–1995   Venezuelan    Male     1908.0
# 37514              NaN  Venezuelan, 1908–1995   Venezuelan    Male     1908.0
# ...                ...                    ...          ...     ...        ...
# 38133              NaN                    NaN          NaN     NaN        0.0
# 38134              NaN                    NaN          NaN     NaN        0.0
# 38135              NaN                    NaN          NaN     NaN        0.0
# 38136              NaN                    NaN          NaN     NaN        0.0
# 38137              NaN                    NaN          NaN     NaN        0.0
#
#        EndDate    Aspect  CenturyBorn
# 37502   1995.0  0.743802         20th
# 37510      0.0  0.885827         20th
# 37512   1995.0  0.734694         20th
# 37513   1995.0  1.379310         20th
# 37514   1995.0  0.689516         20th
# ...        ...       ...          ...
# 38133      0.0  1.750000      unknown
# 38134      0.0  1.619512      unknown
# 38135      0.0  0.843137      unknown
# 38136      0.0  1.509780      unknown
# 38137      0.0  3.409091      unknown
#
# [163 rows x 28 columns]

# %% [markdown]
# ## Further resources
#
# ### Filled version of this notebook
#
# [Python Open Labs Week 3 unfilled notebook](https://colab.research.google.com/github/ncsu-libraries-data-vis/python-open-labs/blob/main/Open_Lab_3_data_wrangling_with_pandas/Open_Lab_3_data_wrangling_with_pandas.ipynb) - a version of this notebook without code filled in for the guided activity and exercises. Use the unfilled version to learn these materials or lead a workshop session
#
# ### Learning resources
#
# - [Python Data Science Handbook](https://jakevdp.github.io/PythonDataScienceHandbook/index.html) - a free, online version of Jake VanderPlas' introduction to data science with Python, includes a chapter on data manipulation with pandas.
# - [Python Programming for Data Science](https://www.tomasbeuzen.com/python-programming-for-data-science/README.html) - a website providing a great overview of conducting data science with Python including pandas.
# - [Real Python](https://realpython.com/) contains a lot of different tutorials at different levels
# - [LinkedIn Learning](https://www.lynda.com/Python-training-tutorials/415-0.html) is free with NC State accounts and contains several video series for learning Python
# - [Dataquest](https://www.dataquest.io/) is a free then paid series of courses with an emphasis on data science
#
# ### Finding help with pandas
#
# The [Pandas website](https://pandas.pydata.org/) and [online documentation](http://pandas.pydata.org/pandas-docs/stable/) are useful resources, and of course the indispensible [Stack Overflow has a "pandas" tag](https://stackoverflow.com/questions/tagged/pandas).  There is also a (much younger, much smaller) [sister site dedicated to Data Science questions that has a "pandas" tag](https://datascience.stackexchange.com/questions/tagged/pandas) too.

# %% [markdown]
# ## Evaluation Survey
# Please, spend 1 minute answering these questions that help improve future workshops.
#
# [go.ncsu.edu/dvs-eval](https://go.ncsu.edu/dvs-eval)

# %% [markdown]
# ## Credits
#
# This workshop was created by Claire Cahoon and Walt Gurley, adapted from previous workshop materials by Scott Bailey and Simon Wiles, of Stanford Libraries.
